# %%
import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd # this module is useful to work with tabular data
import random # this module will be used to select random samples from a collection
import os # this module will be used just to create directories in the local filesystem
from tqdm import tqdm # this module is useful to plot progress bars
import plotly.io as pio
pio.renderers.default = 'colab'

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import plotly.express as px

# %% [markdown]
# ## 1. Import dataset

# %%
data_dir = 'dataset'
### With these commands the train and test datasets, respectively, are downloaded
### automatically and stored in the local "data_dir" directory.
train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning:
#
# The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)

# %%
fig, axs = plt.subplots(5, 5, figsize=(8,8))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like object (basically anything that can be accessed with an index, like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform
# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)

#random_split randomly split a dataset into non-overlapping new datasets of given lengths
#train (55,000 images), val split (5,000 images)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %% [markdown]
# ## 2. Define Convolutional Autoencoder

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            #nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            #nn.BatchNorm2d(32),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        ### Linear section
        self.encoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        # Apply convolutions
        x = self.encoder_cnn(x)
        # Flatten
        x = self.flatten(x)
        # # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        ### Linear section
        self.decoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        ### Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        ### Convolutional section
        self.decoder_conv = nn.Sequential(
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        # Apply linear layers
        x = self.decoder_lin(x)
        # Unflatten
        x = self.unflatten(x)
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# ## 3. Initialize Loss function and the optimizer

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 4

#model = Autoencoder(encoded_space_dim=encoded_space_dim)
encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d,fc2_input_dim=128)

# %%
### Some examples
# Take an input image (remember to add the batch dimension)
img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)
# Encode the image

img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
#dec_img = model(img)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001
#lr = 0.0008 # Learning rate


params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)
#optim = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=6e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
#model.to(device)
# Out:
# Selected device: cuda
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %% [markdown]
# ## 4. Train and evaluate model

# %%
### Training function
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
      ax = plt.subplot(2,n,i+1)
      img = test_dataset[i][0].unsqueeze(0).to(device)
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img))
      plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(2, n, i + 1 + n)
      plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 30
history={'train_loss':[],'val_loss':[]}
for epoch in range(num_epochs):

   train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
   val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)
   print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
   history['train_loss'].append(train_loss)
   history['val_loss'].append(val_loss)
   plot_ae_outputs(encoder,decoder,n=5)
# Out:
# 	 partial train loss (single batch): 0.253071
# 	 partial train loss (single batch): 0.246623
# 	 partial train loss (single batch): 0.240046
# 	 partial train loss (single batch): 0.236102
# 	 partial train loss (single batch): 0.232017
# 	 partial train loss (single batch): 0.227850
# 	 partial train loss (single batch): 0.225047
# 	 partial train loss (single batch): 0.222485
# 	 partial train loss (single batch): 0.219658
# 	 partial train loss (single batch): 0.217869
# 	 partial train loss (single batch): 0.215896
# 	 partial train loss (single batch): 0.213652
# 	 partial train loss (single batch): 0.211206
# 	 partial train loss (single batch): 0.209193
# 	 partial train loss (single batch): 0.207377
# 	 partial train loss (single batch): 0.205306
# 	 partial train loss (single batch): 0.203319
# 	 partial train loss (single batch): 0.201178
# 	 partial train loss (single batch): 0.199227
# 	 partial train loss (single batch): 0.197082
# 	 partial train loss (single batch): 0.195995
# 	 partial train loss (single batch): 0.194065
# 	 partial train loss (single batch): 0.192311
# 	 partial train loss (single batch): 0.190512
# 	 partial train loss (single batch): 0.188939
# 	 partial train loss (single batch): 0.187233
# 	 partial train loss (single batch): 0.185339
# 	 partial train loss (single batch): 0.183333
# 	 partial train loss (single batch): 0.182347
# 	 partial train loss (single batch): 0.180650
# 	 partial train loss (single batch): 0.178899
# 	 partial train loss (single batch): 0.177522
# 	 partial train loss (single batch): 0.176088
# 	 partial train loss (single batch): 0.174806
# 	 partial train loss (single batch): 0.173065
# 	 partial train loss (single batch): 0.172155
# 	 partial train loss (single batch): 0.170578
# 	 partial train loss (single batch): 0.168988
# 	 partial train loss (single batch): 0.167476
# 	 partial train loss (single batch): 0.165865
# 	 partial train loss (single batch): 0.164805
# 	 partial train loss (single batch): 0.163952
# 	 partial train loss (single batch): 0.162455
# 	 partial train loss (single batch): 0.160847
# 	 partial train loss (single batch): 0.159456
# 	 partial train loss (single batch): 0.158071
# 	 partial train loss (single batch): 0.157065
# 	 partial train loss (single batch): 0.155473
# 	 partial train loss (single batch): 0.154817
# 	 partial train loss (single batch): 0.153227
# 	 partial train loss (single batch): 0.151982
# 	 partial train loss (single batch): 0.151654
# 	 partial train loss (single batch): 0.150107
# 	 partial train loss (single batch): 0.148789
# 	 partial train loss (single batch): 0.147556
# 	 partial train loss (single batch): 0.145795
# 	 partial train loss (single batch): 0.145343
# 	 partial train loss (single batch): 0.143856
# 	 partial train loss (single batch): 0.143427
# 	 partial train loss (single batch): 0.141848
# 	 partial train loss (single batch): 0.139976
# 	 partial train loss (single batch): 0.139649
# 	 partial train loss (single batch): 0.138754
# 	 partial train loss (single batch): 0.137495
# 	 partial train loss (single batch): 0.136730
# 	 partial train loss (single batch): 0.135366
# 	 partial train loss (single batch): 0.133810
# 	 partial train loss (single batch): 0.133300
# 	 partial train loss (single batch): 0.132699
# 	 partial train loss (single batch): 0.130833
# 	 partial train loss (single batch): 0.130564
# 	 partial train loss (single batch): 0.129201
# 	 partial train loss (single batch): 0.128298
# 	 partial train loss (single batch): 0.127497
# 	 partial train loss (single batch): 0.126053
# 	 partial train loss (single batch): 0.125412
# 	 partial train loss (single batch): 0.124349
# 	 partial train loss (single batch): 0.122724
# 	 partial train loss (single batch): 0.122591
# 	 partial train loss (single batch): 0.121696
# 	 partial train loss (single batch): 0.120282
# 	 partial train loss (single batch): 0.120068
# 	 partial train loss (single batch): 0.118849
# 	 partial train loss (single batch): 0.117838
# 	 partial train loss (single batch): 0.117427
# 	 partial train loss (single batch): 0.116399
# 	 partial train loss (single batch): 0.115349
# 	 partial train loss (single batch): 0.114852
# 	 partial train loss (single batch): 0.113479
# 	 partial train loss (single batch): 0.112710
# 	 partial train loss (single batch): 0.112420
# 	 partial train loss (single batch): 0.111038
# 	 partial train loss (single batch): 0.110177
# 	 partial train loss (single batch): 0.110081
# 	 partial train loss (single batch): 0.109081
# 	 partial train loss (single batch): 0.107704
# 	 partial train loss (single batch): 0.107377
# 	 partial train loss (single batch): 0.106748
# 	 partial train loss (single batch): 0.105957
# 	 partial train loss (single batch): 0.105920
# 	 partial train loss (single batch): 0.105103
# 	 partial train loss (single batch): 0.103690
# 	 partial train loss (single batch): 0.103228
# 	 partial train loss (single batch): 0.102507
# 	 partial train loss (single batch): 0.101248
# 	 partial train loss (single batch): 0.101314
# 	 partial train loss (single batch): 0.100833
# 	 partial train loss (single batch): 0.100101
# 	 partial train loss (single batch): 0.098956
# 	 partial train loss (single batch): 0.097979
# 	 partial train loss (single batch): 0.096937
# 	 partial train loss (single batch): 0.097494
# 	 partial train loss (single batch): 0.096918
# 	 partial train loss (single batch): 0.095796
# 	 partial train loss (single batch): 0.094958
# 	 partial train loss (single batch): 0.094582
# 	 partial train loss (single batch): 0.093643
# 	 partial train loss (single batch): 0.093579
# 	 partial train loss (single batch): 0.093631
# 	 partial train loss (single batch): 0.092207
# 	 partial train loss (single batch): 0.092172
# 	 partial train loss (single batch): 0.091740
# 	 partial train loss (single batch): 0.090476
# 	 partial train loss (single batch): 0.090922
# 	 partial train loss (single batch): 0.090188
# 	 partial train loss (single batch): 0.089383
# 	 partial train loss (single batch): 0.088677
# 	 partial train loss (single batch): 0.087740
# 	 partial train loss (single batch): 0.087885
# 	 partial train loss (single batch): 0.086886
# 	 partial train loss (single batch): 0.087145
# 	 partial train loss (single batch): 0.085142
# 	 partial train loss (single batch): 0.085551
# 	 partial train loss (single batch): 0.084899
# 	 partial train loss (single batch): 0.084922
# 	 partial train loss (single batch): 0.083197
# 	 partial train loss (single batch): 0.082860
# 	 partial train loss (single batch): 0.083977
# 	 partial train loss (single batch): 0.082633
# 	 partial train loss (single batch): 0.082544
# 	 partial train loss (single batch): 0.082307
# 	 partial train loss (single batch): 0.081641
# 	 partial train loss (single batch): 0.080524
# 	 partial train loss (single batch): 0.080596
# 	 partial train loss (single batch): 0.080806
# 	 partial train loss (single batch): 0.079871
# 	 partial train loss (single batch): 0.078363
# 	 partial train loss (single batch): 0.078574
# 	 partial train loss (single batch): 0.078025
# 	 partial train loss (single batch): 0.077266
# 	 partial train loss (single batch): 0.078437
# 	 partial train loss (single batch): 0.077975
# 	 partial train loss (single batch): 0.076423
# 	 partial train loss (single batch): 0.075877
# 	 partial train loss (single batch): 0.076283
# 	 partial train loss (single batch): 0.075549
# 	 partial train loss (single batch): 0.075857
# 	 partial train loss (single batch): 0.074769
# 	 partial train loss (single batch): 0.073625
# 	 partial train loss (single batch): 0.073335
# 	 partial train loss (single batch): 0.073936
# 	 partial train loss (single batch): 0.074840
# 	 partial train loss (single batch): 0.073958
# 	 partial train loss (single batch): 0.073169
# 	 partial train loss (single batch): 0.072835
# 	 partial train loss (single batch): 0.071051
# 	 partial train loss (single batch): 0.071893
# 	 partial train loss (single batch): 0.071545
# 	 partial train loss (single batch): 0.071816
# 	 partial train loss (single batch): 0.071198
# 	 partial train loss (single batch): 0.069151
# 	 partial train loss (single batch): 0.068994
# 	 partial train loss (single batch): 0.071140
# 	 partial train loss (single batch): 0.069304
# 	 partial train loss (single batch): 0.068547
# 	 partial train loss (single batch): 0.069779
# 	 partial train loss (single batch): 0.068657
# 	 partial train loss (single batch): 0.069638
# 	 partial train loss (single batch): 0.069351
# 	 partial train loss (single batch): 0.068817
# 	 partial train loss (single batch): 0.067962
# 	 partial train loss (single batch): 0.067789
# 	 partial train loss (single batch): 0.068148
# 	 partial train loss (single batch): 0.065472
# 	 partial train loss (single batch): 0.067565
# 	 partial train loss (single batch): 0.066083
# 	 partial train loss (single batch): 0.067831
# 	 partial train loss (single batch): 0.066439
#
#  EPOCH 1/30 	 train loss 0.123 	 val loss 0.065
# 	 partial train loss (single batch): 0.066099
# 	 partial train loss (single batch): 0.065267
# 	 partial train loss (single batch): 0.066149
# 	 partial train loss (single batch): 0.065695
# 	 partial train loss (single batch): 0.065135
# 	 partial train loss (single batch): 0.065599
# 	 partial train loss (single batch): 0.064899
# 	 partial train loss (single batch): 0.063811
# 	 partial train loss (single batch): 0.064354
# 	 partial train loss (single batch): 0.063705
# 	 partial train loss (single batch): 0.063492
# 	 partial train loss (single batch): 0.063629
# 	 partial train loss (single batch): 0.062771
# 	 partial train loss (single batch): 0.064003
# 	 partial train loss (single batch): 0.062663
# 	 partial train loss (single batch): 0.062843
# 	 partial train loss (single batch): 0.062039
# 	 partial train loss (single batch): 0.063197
# 	 partial train loss (single batch): 0.061868
# 	 partial train loss (single batch): 0.061615
# 	 partial train loss (single batch): 0.061433
# 	 partial train loss (single batch): 0.061792
# 	 partial train loss (single batch): 0.061624
# 	 partial train loss (single batch): 0.061890
# 	 partial train loss (single batch): 0.061330
# 	 partial train loss (single batch): 0.058935
# 	 partial train loss (single batch): 0.059553
# 	 partial train loss (single batch): 0.060855
# 	 partial train loss (single batch): 0.060700
# 	 partial train loss (single batch): 0.059607
# 	 partial train loss (single batch): 0.060167
# 	 partial train loss (single batch): 0.060204
# 	 partial train loss (single batch): 0.059745
# 	 partial train loss (single batch): 0.060412
# 	 partial train loss (single batch): 0.059553
# 	 partial train loss (single batch): 0.061102
# 	 partial train loss (single batch): 0.060070
# 	 partial train loss (single batch): 0.059945
# 	 partial train loss (single batch): 0.059743
# 	 partial train loss (single batch): 0.058460
# 	 partial train loss (single batch): 0.057358
# 	 partial train loss (single batch): 0.058195
# 	 partial train loss (single batch): 0.057951
# 	 partial train loss (single batch): 0.057968
# 	 partial train loss (single batch): 0.057088
# 	 partial train loss (single batch): 0.058443
# 	 partial train loss (single batch): 0.056553
# 	 partial train loss (single batch): 0.056647
# 	 partial train loss (single batch): 0.058259
# 	 partial train loss (single batch): 0.056758
# 	 partial train loss (single batch): 0.057228
# 	 partial train loss (single batch): 0.057234
# 	 partial train loss (single batch): 0.057519
# 	 partial train loss (single batch): 0.057304
# 	 partial train loss (single batch): 0.057151
# 	 partial train loss (single batch): 0.055670
# 	 partial train loss (single batch): 0.057438
# 	 partial train loss (single batch): 0.056541
# 	 partial train loss (single batch): 0.056907
# 	 partial train loss (single batch): 0.055497
# 	 partial train loss (single batch): 0.055685
# 	 partial train loss (single batch): 0.056034
# 	 partial train loss (single batch): 0.055886
# 	 partial train loss (single batch): 0.055530
# 	 partial train loss (single batch): 0.056141
# 	 partial train loss (single batch): 0.056132
# 	 partial train loss (single batch): 0.054401
# 	 partial train loss (single batch): 0.055581
# 	 partial train loss (single batch): 0.055343
# 	 partial train loss (single batch): 0.054363
# 	 partial train loss (single batch): 0.055635
# 	 partial train loss (single batch): 0.054065
# 	 partial train loss (single batch): 0.053429
# 	 partial train loss (single batch): 0.054777
# 	 partial train loss (single batch): 0.054445
# 	 partial train loss (single batch): 0.054697
# 	 partial train loss (single batch): 0.054608
# 	 partial train loss (single batch): 0.052890
# 	 partial train loss (single batch): 0.053805
# 	 partial train loss (single batch): 0.054099
# 	 partial train loss (single batch): 0.053046
# 	 partial train loss (single batch): 0.053349
# 	 partial train loss (single batch): 0.054104
# 	 partial train loss (single batch): 0.053783
# 	 partial train loss (single batch): 0.054729
# 	 partial train loss (single batch): 0.053605
# 	 partial train loss (single batch): 0.053269
# 	 partial train loss (single batch): 0.054367
# 	 partial train loss (single batch): 0.053269
# 	 partial train loss (single batch): 0.053118
# 	 partial train loss (single batch): 0.054254
# 	 partial train loss (single batch): 0.052276
# 	 partial train loss (single batch): 0.052169
# 	 partial train loss (single batch): 0.052741
# 	 partial train loss (single batch): 0.052801
# 	 partial train loss (single batch): 0.051369
# 	 partial train loss (single batch): 0.052736
# 	 partial train loss (single batch): 0.052854
# 	 partial train loss (single batch): 0.052671
# 	 partial train loss (single batch): 0.053619
# 	 partial train loss (single batch): 0.051876
# 	 partial train loss (single batch): 0.051761
# 	 partial train loss (single batch): 0.051862
# 	 partial train loss (single batch): 0.052548
# 	 partial train loss (single batch): 0.050932
# 	 partial train loss (single batch): 0.050926
# 	 partial train loss (single batch): 0.052461
# 	 partial train loss (single batch): 0.052508
# 	 partial train loss (single batch): 0.051205
# 	 partial train loss (single batch): 0.050123
# 	 partial train loss (single batch): 0.049247
# 	 partial train loss (single batch): 0.051592
# 	 partial train loss (single batch): 0.051576
# 	 partial train loss (single batch): 0.050683
# 	 partial train loss (single batch): 0.051503
# 	 partial train loss (single batch): 0.051240
# 	 partial train loss (single batch): 0.049830
# 	 partial train loss (single batch): 0.050836
# 	 partial train loss (single batch): 0.051738
# 	 partial train loss (single batch): 0.051069
# 	 partial train loss (single batch): 0.051932
# 	 partial train loss (single batch): 0.051282
# 	 partial train loss (single batch): 0.050627
# 	 partial train loss (single batch): 0.051548
# 	 partial train loss (single batch): 0.051114
# 	 partial train loss (single batch): 0.050313
# 	 partial train loss (single batch): 0.050561
# 	 partial train loss (single batch): 0.049632
# 	 partial train loss (single batch): 0.050134
# 	 partial train loss (single batch): 0.049836
# 	 partial train loss (single batch): 0.050292
# 	 partial train loss (single batch): 0.048898
# 	 partial train loss (single batch): 0.049542
# 	 partial train loss (single batch): 0.049172
# 	 partial train loss (single batch): 0.049760
# 	 partial train loss (single batch): 0.047775
# 	 partial train loss (single batch): 0.048398
# 	 partial train loss (single batch): 0.050460
# 	 partial train loss (single batch): 0.049006
# 	 partial train loss (single batch): 0.049148
# 	 partial train loss (single batch): 0.050180
# 	 partial train loss (single batch): 0.049476
# 	 partial train loss (single batch): 0.048657
# 	 partial train loss (single batch): 0.048819
# 	 partial train loss (single batch): 0.049951
# 	 partial train loss (single batch): 0.049369
# 	 partial train loss (single batch): 0.047479
# 	 partial train loss (single batch): 0.048172
# 	 partial train loss (single batch): 0.048052
# 	 partial train loss (single batch): 0.047868
# 	 partial train loss (single batch): 0.049155
# 	 partial train loss (single batch): 0.049573
# 	 partial train loss (single batch): 0.048031
# 	 partial train loss (single batch): 0.047417
# 	 partial train loss (single batch): 0.048939
# 	 partial train loss (single batch): 0.048245
# 	 partial train loss (single batch): 0.048718
# 	 partial train loss (single batch): 0.047763
# 	 partial train loss (single batch): 0.046606
# 	 partial train loss (single batch): 0.047016
# 	 partial train loss (single batch): 0.047881
# 	 partial train loss (single batch): 0.049349
# 	 partial train loss (single batch): 0.049264
# 	 partial train loss (single batch): 0.048372
# 	 partial train loss (single batch): 0.048315
# 	 partial train loss (single batch): 0.046394
# 	 partial train loss (single batch): 0.047907
# 	 partial train loss (single batch): 0.047721
# 	 partial train loss (single batch): 0.048005
# 	 partial train loss (single batch): 0.048059
# 	 partial train loss (single batch): 0.045159
# 	 partial train loss (single batch): 0.045748
# 	 partial train loss (single batch): 0.049017
# 	 partial train loss (single batch): 0.046375
# 	 partial train loss (single batch): 0.046060
# 	 partial train loss (single batch): 0.047275
# 	 partial train loss (single batch): 0.046087
# 	 partial train loss (single batch): 0.048694
# 	 partial train loss (single batch): 0.048772
# 	 partial train loss (single batch): 0.048118
# 	 partial train loss (single batch): 0.047143
# 	 partial train loss (single batch): 0.047306
# 	 partial train loss (single batch): 0.048322
# 	 partial train loss (single batch): 0.044551
# 	 partial train loss (single batch): 0.047727
# 	 partial train loss (single batch): 0.045767
# 	 partial train loss (single batch): 0.048216
# 	 partial train loss (single batch): 0.046390
#
#  EPOCH 2/30 	 train loss 0.054 	 val loss 0.047
# 	 partial train loss (single batch): 0.046845
# 	 partial train loss (single batch): 0.045695
# 	 partial train loss (single batch): 0.047543
# 	 partial train loss (single batch): 0.046881
# 	 partial train loss (single batch): 0.046636
# 	 partial train loss (single batch): 0.047569
# 	 partial train loss (single batch): 0.046704
# 	 partial train loss (single batch): 0.045436
# 	 partial train loss (single batch): 0.046159
# 	 partial train loss (single batch): 0.045649
# 	 partial train loss (single batch): 0.045674
# 	 partial train loss (single batch): 0.045898
# 	 partial train loss (single batch): 0.045504
# 	 partial train loss (single batch): 0.047222
# 	 partial train loss (single batch): 0.044995
# 	 partial train loss (single batch): 0.045637
# 	 partial train loss (single batch): 0.045062
# 	 partial train loss (single batch): 0.046329
# 	 partial train loss (single batch): 0.045254
# 	 partial train loss (single batch): 0.045251
# 	 partial train loss (single batch): 0.045314
# 	 partial train loss (single batch): 0.045453
# 	 partial train loss (single batch): 0.045704
# 	 partial train loss (single batch): 0.045910
# 	 partial train loss (single batch): 0.046119
# 	 partial train loss (single batch): 0.043003
# 	 partial train loss (single batch): 0.043978
# 	 partial train loss (single batch): 0.045578
# 	 partial train loss (single batch): 0.045401
# 	 partial train loss (single batch): 0.044700
# 	 partial train loss (single batch): 0.045351
# 	 partial train loss (single batch): 0.045589
# 	 partial train loss (single batch): 0.045480
# 	 partial train loss (single batch): 0.045766
# 	 partial train loss (single batch): 0.045433
# 	 partial train loss (single batch): 0.046771
# 	 partial train loss (single batch): 0.045291
# 	 partial train loss (single batch): 0.045825
# 	 partial train loss (single batch): 0.045462
# 	 partial train loss (single batch): 0.044394
# 	 partial train loss (single batch): 0.043442
# 	 partial train loss (single batch): 0.044202
# 	 partial train loss (single batch): 0.043938
# 	 partial train loss (single batch): 0.044236
# 	 partial train loss (single batch): 0.043112
# 	 partial train loss (single batch): 0.045040
# 	 partial train loss (single batch): 0.042653
# 	 partial train loss (single batch): 0.042969
# 	 partial train loss (single batch): 0.044531
# 	 partial train loss (single batch): 0.043696
# 	 partial train loss (single batch): 0.044509
# 	 partial train loss (single batch): 0.044078
# 	 partial train loss (single batch): 0.044659
# 	 partial train loss (single batch): 0.044580
# 	 partial train loss (single batch): 0.044235
# 	 partial train loss (single batch): 0.042676
# 	 partial train loss (single batch): 0.044604
# 	 partial train loss (single batch): 0.043641
# 	 partial train loss (single batch): 0.044175
# 	 partial train loss (single batch): 0.043079
# 	 partial train loss (single batch): 0.043053
# 	 partial train loss (single batch): 0.043731
# 	 partial train loss (single batch): 0.043360
# 	 partial train loss (single batch): 0.043258
# 	 partial train loss (single batch): 0.043915
# 	 partial train loss (single batch): 0.043857
# 	 partial train loss (single batch): 0.042728
# 	 partial train loss (single batch): 0.043531
# 	 partial train loss (single batch): 0.043510
# 	 partial train loss (single batch): 0.042425
# 	 partial train loss (single batch): 0.043733
# 	 partial train loss (single batch): 0.042038
# 	 partial train loss (single batch): 0.041095
# 	 partial train loss (single batch): 0.042778
# 	 partial train loss (single batch): 0.042934
# 	 partial train loss (single batch): 0.043361
# 	 partial train loss (single batch): 0.043027
# 	 partial train loss (single batch): 0.041527
# 	 partial train loss (single batch): 0.042092
# 	 partial train loss (single batch): 0.042631
# 	 partial train loss (single batch): 0.042148
# 	 partial train loss (single batch): 0.041620
# 	 partial train loss (single batch): 0.042896
# 	 partial train loss (single batch): 0.042945
# 	 partial train loss (single batch): 0.043793
# 	 partial train loss (single batch): 0.042289
# 	 partial train loss (single batch): 0.042854
# 	 partial train loss (single batch): 0.043156
# 	 partial train loss (single batch): 0.042456
# 	 partial train loss (single batch): 0.042044
# 	 partial train loss (single batch): 0.043378
# 	 partial train loss (single batch): 0.041936
# 	 partial train loss (single batch): 0.041679
# 	 partial train loss (single batch): 0.042015
# 	 partial train loss (single batch): 0.041958
# 	 partial train loss (single batch): 0.040471
# 	 partial train loss (single batch): 0.041791
# 	 partial train loss (single batch): 0.042605
# 	 partial train loss (single batch): 0.042166
# 	 partial train loss (single batch): 0.043094
# 	 partial train loss (single batch): 0.041038
# 	 partial train loss (single batch): 0.041405
# 	 partial train loss (single batch): 0.041460
# 	 partial train loss (single batch): 0.042119
# 	 partial train loss (single batch): 0.040943
# 	 partial train loss (single batch): 0.040999
# 	 partial train loss (single batch): 0.042348
# 	 partial train loss (single batch): 0.042169
# 	 partial train loss (single batch): 0.040778
# 	 partial train loss (single batch): 0.039891
# 	 partial train loss (single batch): 0.039607
# 	 partial train loss (single batch): 0.041425
# 	 partial train loss (single batch): 0.041675
# 	 partial train loss (single batch): 0.040459
# 	 partial train loss (single batch): 0.041855
# 	 partial train loss (single batch): 0.041550
# 	 partial train loss (single batch): 0.039725
# 	 partial train loss (single batch): 0.040424
# 	 partial train loss (single batch): 0.041788
# 	 partial train loss (single batch): 0.041561
# 	 partial train loss (single batch): 0.042274
# 	 partial train loss (single batch): 0.041494
# 	 partial train loss (single batch): 0.041118
# 	 partial train loss (single batch): 0.042071
# 	 partial train loss (single batch): 0.041859
# 	 partial train loss (single batch): 0.041010
# 	 partial train loss (single batch): 0.041250
# 	 partial train loss (single batch): 0.039864
# 	 partial train loss (single batch): 0.040364
# 	 partial train loss (single batch): 0.040139
# 	 partial train loss (single batch): 0.040427
# 	 partial train loss (single batch): 0.039764
# 	 partial train loss (single batch): 0.039688
# 	 partial train loss (single batch): 0.039815
# 	 partial train loss (single batch): 0.040537
# 	 partial train loss (single batch): 0.038157
# 	 partial train loss (single batch): 0.039269
# 	 partial train loss (single batch): 0.040655
# 	 partial train loss (single batch): 0.039542
# 	 partial train loss (single batch): 0.039612
# 	 partial train loss (single batch): 0.041106
# 	 partial train loss (single batch): 0.040181
# 	 partial train loss (single batch): 0.039509
# 	 partial train loss (single batch): 0.039463
# 	 partial train loss (single batch): 0.040717
# 	 partial train loss (single batch): 0.040095
# 	 partial train loss (single batch): 0.038851
# 	 partial train loss (single batch): 0.038786
# 	 partial train loss (single batch): 0.038865
# 	 partial train loss (single batch): 0.038936
# 	 partial train loss (single batch): 0.039713
# 	 partial train loss (single batch): 0.040123
# 	 partial train loss (single batch): 0.039244
# 	 partial train loss (single batch): 0.038208
# 	 partial train loss (single batch): 0.039812
# 	 partial train loss (single batch): 0.039218
# 	 partial train loss (single batch): 0.039570
# 	 partial train loss (single batch): 0.038627
# 	 partial train loss (single batch): 0.037091
# 	 partial train loss (single batch): 0.038692
# 	 partial train loss (single batch): 0.038942
# 	 partial train loss (single batch): 0.040633
# 	 partial train loss (single batch): 0.040468
# 	 partial train loss (single batch): 0.040299
# 	 partial train loss (single batch): 0.039776
# 	 partial train loss (single batch): 0.037675
# 	 partial train loss (single batch): 0.039266
# 	 partial train loss (single batch): 0.038760
# 	 partial train loss (single batch): 0.038801
# 	 partial train loss (single batch): 0.039361
# 	 partial train loss (single batch): 0.036609
# 	 partial train loss (single batch): 0.037206
# 	 partial train loss (single batch): 0.040363
# 	 partial train loss (single batch): 0.037738
# 	 partial train loss (single batch): 0.037814
# 	 partial train loss (single batch): 0.038429
# 	 partial train loss (single batch): 0.037042
# 	 partial train loss (single batch): 0.040687
# 	 partial train loss (single batch): 0.040242
# 	 partial train loss (single batch): 0.039952
# 	 partial train loss (single batch): 0.039101
# 	 partial train loss (single batch): 0.038525
# 	 partial train loss (single batch): 0.040205
# 	 partial train loss (single batch): 0.035989
# 	 partial train loss (single batch): 0.039154
# 	 partial train loss (single batch): 0.037336
# 	 partial train loss (single batch): 0.039671
# 	 partial train loss (single batch): 0.037222
#
#  EPOCH 3/30 	 train loss 0.042 	 val loss 0.039
# 	 partial train loss (single batch): 0.038662
# 	 partial train loss (single batch): 0.036969
# 	 partial train loss (single batch): 0.038640
# 	 partial train loss (single batch): 0.038655
# 	 partial train loss (single batch): 0.038587
# 	 partial train loss (single batch): 0.039072
# 	 partial train loss (single batch): 0.038880
# 	 partial train loss (single batch): 0.036878
# 	 partial train loss (single batch): 0.037940
# 	 partial train loss (single batch): 0.037334
# 	 partial train loss (single batch): 0.036970
# 	 partial train loss (single batch): 0.037802
# 	 partial train loss (single batch): 0.037523
# 	 partial train loss (single batch): 0.038765
# 	 partial train loss (single batch): 0.036601
# 	 partial train loss (single batch): 0.037529
# 	 partial train loss (single batch): 0.036605
# 	 partial train loss (single batch): 0.038279
# 	 partial train loss (single batch): 0.036621
# 	 partial train loss (single batch): 0.037460
# 	 partial train loss (single batch): 0.037120
# 	 partial train loss (single batch): 0.037075
# 	 partial train loss (single batch): 0.037673
# 	 partial train loss (single batch): 0.038160
# 	 partial train loss (single batch): 0.038051
# 	 partial train loss (single batch): 0.035542
# 	 partial train loss (single batch): 0.036008
# 	 partial train loss (single batch): 0.037630
# 	 partial train loss (single batch): 0.037577
# 	 partial train loss (single batch): 0.036694
# 	 partial train loss (single batch): 0.037767
# 	 partial train loss (single batch): 0.037948
# 	 partial train loss (single batch): 0.037846
# 	 partial train loss (single batch): 0.037932
# 	 partial train loss (single batch): 0.038284
# 	 partial train loss (single batch): 0.038672
# 	 partial train loss (single batch): 0.037511
# 	 partial train loss (single batch): 0.038186
# 	 partial train loss (single batch): 0.037640
# 	 partial train loss (single batch): 0.036935
# 	 partial train loss (single batch): 0.035966
# 	 partial train loss (single batch): 0.036527
# 	 partial train loss (single batch): 0.036213
# 	 partial train loss (single batch): 0.036931
# 	 partial train loss (single batch): 0.035690
# 	 partial train loss (single batch): 0.037459
# 	 partial train loss (single batch): 0.034807
# 	 partial train loss (single batch): 0.035407
# 	 partial train loss (single batch): 0.036329
# 	 partial train loss (single batch): 0.036444
# 	 partial train loss (single batch): 0.037353
# 	 partial train loss (single batch): 0.036929
# 	 partial train loss (single batch): 0.037326
# 	 partial train loss (single batch): 0.036931
# 	 partial train loss (single batch): 0.036777
# 	 partial train loss (single batch): 0.035405
# 	 partial train loss (single batch): 0.037413
# 	 partial train loss (single batch): 0.036112
# 	 partial train loss (single batch): 0.036786
# 	 partial train loss (single batch): 0.036030
# 	 partial train loss (single batch): 0.036291
# 	 partial train loss (single batch): 0.036402
# 	 partial train loss (single batch): 0.036002
# 	 partial train loss (single batch): 0.036699
# 	 partial train loss (single batch): 0.036852
# 	 partial train loss (single batch): 0.036798
# 	 partial train loss (single batch): 0.036357
# 	 partial train loss (single batch): 0.036534
# 	 partial train loss (single batch): 0.036252
# 	 partial train loss (single batch): 0.035156
# 	 partial train loss (single batch): 0.036612
# 	 partial train loss (single batch): 0.034961
# 	 partial train loss (single batch): 0.033809
# 	 partial train loss (single batch): 0.034777
# 	 partial train loss (single batch): 0.035796
# 	 partial train loss (single batch): 0.036699
# 	 partial train loss (single batch): 0.035474
# 	 partial train loss (single batch): 0.034882
# 	 partial train loss (single batch): 0.034902
# 	 partial train loss (single batch): 0.035413
# 	 partial train loss (single batch): 0.035886
# 	 partial train loss (single batch): 0.034197
# 	 partial train loss (single batch): 0.036439
# 	 partial train loss (single batch): 0.035788
# 	 partial train loss (single batch): 0.037232
# 	 partial train loss (single batch): 0.035204
# 	 partial train loss (single batch): 0.036916
# 	 partial train loss (single batch): 0.036247
# 	 partial train loss (single batch): 0.036180
# 	 partial train loss (single batch): 0.035169
# 	 partial train loss (single batch): 0.036450
# 	 partial train loss (single batch): 0.035862
# 	 partial train loss (single batch): 0.035399
# 	 partial train loss (single batch): 0.035310
# 	 partial train loss (single batch): 0.035385
# 	 partial train loss (single batch): 0.033615
# 	 partial train loss (single batch): 0.035112
# 	 partial train loss (single batch): 0.036738
# 	 partial train loss (single batch): 0.036106
# 	 partial train loss (single batch): 0.036139
# 	 partial train loss (single batch): 0.034566
# 	 partial train loss (single batch): 0.035292
# 	 partial train loss (single batch): 0.035212
# 	 partial train loss (single batch): 0.035743
# 	 partial train loss (single batch): 0.034842
# 	 partial train loss (single batch): 0.035274
# 	 partial train loss (single batch): 0.036274
# 	 partial train loss (single batch): 0.035687
# 	 partial train loss (single batch): 0.034331
# 	 partial train loss (single batch): 0.034289
# 	 partial train loss (single batch): 0.033700
# 	 partial train loss (single batch): 0.035335
# 	 partial train loss (single batch): 0.035996
# 	 partial train loss (single batch): 0.034339
# 	 partial train loss (single batch): 0.036117
# 	 partial train loss (single batch): 0.035904
# 	 partial train loss (single batch): 0.033698
# 	 partial train loss (single batch): 0.033972
# 	 partial train loss (single batch): 0.035925
# 	 partial train loss (single batch): 0.035995
# 	 partial train loss (single batch): 0.036924
# 	 partial train loss (single batch): 0.035225
# 	 partial train loss (single batch): 0.035442
# 	 partial train loss (single batch): 0.036816
# 	 partial train loss (single batch): 0.036386
# 	 partial train loss (single batch): 0.035019
# 	 partial train loss (single batch): 0.035865
# 	 partial train loss (single batch): 0.034078
# 	 partial train loss (single batch): 0.034968
# 	 partial train loss (single batch): 0.034418
# 	 partial train loss (single batch): 0.034112
# 	 partial train loss (single batch): 0.034171
# 	 partial train loss (single batch): 0.034252
# 	 partial train loss (single batch): 0.034202
# 	 partial train loss (single batch): 0.035165
# 	 partial train loss (single batch): 0.032801
# 	 partial train loss (single batch): 0.034293
# 	 partial train loss (single batch): 0.035205
# 	 partial train loss (single batch): 0.033841
# 	 partial train loss (single batch): 0.034201
# 	 partial train loss (single batch): 0.035893
# 	 partial train loss (single batch): 0.034722
# 	 partial train loss (single batch): 0.034396
# 	 partial train loss (single batch): 0.034333
# 	 partial train loss (single batch): 0.035529
# 	 partial train loss (single batch): 0.035011
# 	 partial train loss (single batch): 0.033699
# 	 partial train loss (single batch): 0.033434
# 	 partial train loss (single batch): 0.033446
# 	 partial train loss (single batch): 0.033957
# 	 partial train loss (single batch): 0.034067
# 	 partial train loss (single batch): 0.034747
# 	 partial train loss (single batch): 0.034356
# 	 partial train loss (single batch): 0.033084
# 	 partial train loss (single batch): 0.034539
# 	 partial train loss (single batch): 0.034253
# 	 partial train loss (single batch): 0.034499
# 	 partial train loss (single batch): 0.033116
# 	 partial train loss (single batch): 0.032259
# 	 partial train loss (single batch): 0.034148
# 	 partial train loss (single batch): 0.033841
# 	 partial train loss (single batch): 0.035656
# 	 partial train loss (single batch): 0.035207
# 	 partial train loss (single batch): 0.035690
# 	 partial train loss (single batch): 0.035055
# 	 partial train loss (single batch): 0.033100
# 	 partial train loss (single batch): 0.034453
# 	 partial train loss (single batch): 0.034022
# 	 partial train loss (single batch): 0.033680
# 	 partial train loss (single batch): 0.034758
# 	 partial train loss (single batch): 0.032127
# 	 partial train loss (single batch): 0.032598
# 	 partial train loss (single batch): 0.035783
# 	 partial train loss (single batch): 0.033146
# 	 partial train loss (single batch): 0.033369
# 	 partial train loss (single batch): 0.034172
# 	 partial train loss (single batch): 0.032041
# 	 partial train loss (single batch): 0.035900
# 	 partial train loss (single batch): 0.036051
# 	 partial train loss (single batch): 0.035200
# 	 partial train loss (single batch): 0.034519
# 	 partial train loss (single batch): 0.033708
# 	 partial train loss (single batch): 0.035602
# 	 partial train loss (single batch): 0.031233
# 	 partial train loss (single batch): 0.034624
# 	 partial train loss (single batch): 0.032544
# 	 partial train loss (single batch): 0.034961
# 	 partial train loss (single batch): 0.032485
#
#  EPOCH 4/30 	 train loss 0.036 	 val loss 0.034
# 	 partial train loss (single batch): 0.034093
# 	 partial train loss (single batch): 0.032259
# 	 partial train loss (single batch): 0.033924
# 	 partial train loss (single batch): 0.034043
# 	 partial train loss (single batch): 0.034375
# 	 partial train loss (single batch): 0.034684
# 	 partial train loss (single batch): 0.035007
# 	 partial train loss (single batch): 0.032434
# 	 partial train loss (single batch): 0.033807
# 	 partial train loss (single batch): 0.033212
# 	 partial train loss (single batch): 0.032443
# 	 partial train loss (single batch): 0.033474
# 	 partial train loss (single batch): 0.033657
# 	 partial train loss (single batch): 0.034432
# 	 partial train loss (single batch): 0.032324
# 	 partial train loss (single batch): 0.033414
# 	 partial train loss (single batch): 0.032565
# 	 partial train loss (single batch): 0.034073
# 	 partial train loss (single batch): 0.032285
# 	 partial train loss (single batch): 0.033747
# 	 partial train loss (single batch): 0.033271
# 	 partial train loss (single batch): 0.033193
# 	 partial train loss (single batch): 0.033636
# 	 partial train loss (single batch): 0.034662
# 	 partial train loss (single batch): 0.034065
# 	 partial train loss (single batch): 0.031965
# 	 partial train loss (single batch): 0.032093
# 	 partial train loss (single batch): 0.033670
# 	 partial train loss (single batch): 0.033629
# 	 partial train loss (single batch): 0.032832
# 	 partial train loss (single batch): 0.034199
# 	 partial train loss (single batch): 0.034058
# 	 partial train loss (single batch): 0.034011
# 	 partial train loss (single batch): 0.034052
# 	 partial train loss (single batch): 0.034641
# 	 partial train loss (single batch): 0.034669
# 	 partial train loss (single batch): 0.033892
# 	 partial train loss (single batch): 0.034694
# 	 partial train loss (single batch): 0.033957
# 	 partial train loss (single batch): 0.033417
# 	 partial train loss (single batch): 0.032633
# 	 partial train loss (single batch): 0.032930
# 	 partial train loss (single batch): 0.032597
# 	 partial train loss (single batch): 0.033355
# 	 partial train loss (single batch): 0.032125
# 	 partial train loss (single batch): 0.034014
# 	 partial train loss (single batch): 0.031200
# 	 partial train loss (single batch): 0.031814
# 	 partial train loss (single batch): 0.032334
# 	 partial train loss (single batch): 0.032711
# 	 partial train loss (single batch): 0.034111
# 	 partial train loss (single batch): 0.033398
# 	 partial train loss (single batch): 0.033878
# 	 partial train loss (single batch): 0.033554
# 	 partial train loss (single batch): 0.033333
# 	 partial train loss (single batch): 0.032039
# 	 partial train loss (single batch): 0.034115
# 	 partial train loss (single batch): 0.032657
# 	 partial train loss (single batch): 0.033436
# 	 partial train loss (single batch): 0.032749
# 	 partial train loss (single batch): 0.033241
# 	 partial train loss (single batch): 0.032964
# 	 partial train loss (single batch): 0.032702
# 	 partial train loss (single batch): 0.033508
# 	 partial train loss (single batch): 0.033627
# 	 partial train loss (single batch): 0.033359
# 	 partial train loss (single batch): 0.033461
# 	 partial train loss (single batch): 0.033312
# 	 partial train loss (single batch): 0.033065
# 	 partial train loss (single batch): 0.032101
# 	 partial train loss (single batch): 0.033174
# 	 partial train loss (single batch): 0.031842
# 	 partial train loss (single batch): 0.030584
# 	 partial train loss (single batch): 0.031390
# 	 partial train loss (single batch): 0.032620
# 	 partial train loss (single batch): 0.033648
# 	 partial train loss (single batch): 0.032070
# 	 partial train loss (single batch): 0.032009
# 	 partial train loss (single batch): 0.031811
# 	 partial train loss (single batch): 0.032200
# 	 partial train loss (single batch): 0.033126
# 	 partial train loss (single batch): 0.031010
# 	 partial train loss (single batch): 0.033741
# 	 partial train loss (single batch): 0.032481
# 	 partial train loss (single batch): 0.034255
# 	 partial train loss (single batch): 0.032221
# 	 partial train loss (single batch): 0.034138
# 	 partial train loss (single batch): 0.033074
# 	 partial train loss (single batch): 0.033585
# 	 partial train loss (single batch): 0.032143
# 	 partial train loss (single batch): 0.033356
# 	 partial train loss (single batch): 0.033057
# 	 partial train loss (single batch): 0.032376
# 	 partial train loss (single batch): 0.032306
# 	 partial train loss (single batch): 0.032550
# 	 partial train loss (single batch): 0.030705
# 	 partial train loss (single batch): 0.032213
# 	 partial train loss (single batch): 0.034081
# 	 partial train loss (single batch): 0.033339
# 	 partial train loss (single batch): 0.032968
# 	 partial train loss (single batch): 0.031824
# 	 partial train loss (single batch): 0.032876
# 	 partial train loss (single batch): 0.032482
# 	 partial train loss (single batch): 0.032957
# 	 partial train loss (single batch): 0.032287
# 	 partial train loss (single batch): 0.032789
# 	 partial train loss (single batch): 0.033713
# 	 partial train loss (single batch): 0.033183
# 	 partial train loss (single batch): 0.031876
# 	 partial train loss (single batch): 0.031825
# 	 partial train loss (single batch): 0.031324
# 	 partial train loss (single batch): 0.032860
# 	 partial train loss (single batch): 0.033754
# 	 partial train loss (single batch): 0.031773
# 	 partial train loss (single batch): 0.033617
# 	 partial train loss (single batch): 0.033042
# 	 partial train loss (single batch): 0.031084
# 	 partial train loss (single batch): 0.031295
# 	 partial train loss (single batch): 0.033790
# 	 partial train loss (single batch): 0.033066
# 	 partial train loss (single batch): 0.034399
# 	 partial train loss (single batch): 0.032191
# 	 partial train loss (single batch): 0.032856
# 	 partial train loss (single batch): 0.034515
# 	 partial train loss (single batch): 0.034207
# 	 partial train loss (single batch): 0.032094
# 	 partial train loss (single batch): 0.033622
# 	 partial train loss (single batch): 0.031623
# 	 partial train loss (single batch): 0.032344
# 	 partial train loss (single batch): 0.031669
# 	 partial train loss (single batch): 0.031475
# 	 partial train loss (single batch): 0.031353
# 	 partial train loss (single batch): 0.031961
# 	 partial train loss (single batch): 0.031718
# 	 partial train loss (single batch): 0.032762
# 	 partial train loss (single batch): 0.030231
# 	 partial train loss (single batch): 0.031871
# 	 partial train loss (single batch): 0.032803
# 	 partial train loss (single batch): 0.031203
# 	 partial train loss (single batch): 0.031551
# 	 partial train loss (single batch): 0.033506
# 	 partial train loss (single batch): 0.032034
# 	 partial train loss (single batch): 0.031837
# 	 partial train loss (single batch): 0.031952
# 	 partial train loss (single batch): 0.032964
# 	 partial train loss (single batch): 0.032578
# 	 partial train loss (single batch): 0.031293
# 	 partial train loss (single batch): 0.031012
# 	 partial train loss (single batch): 0.031143
# 	 partial train loss (single batch): 0.031603
# 	 partial train loss (single batch): 0.031586
# 	 partial train loss (single batch): 0.032401
# 	 partial train loss (single batch): 0.032160
# 	 partial train loss (single batch): 0.030878
# 	 partial train loss (single batch): 0.032221
# 	 partial train loss (single batch): 0.031836
# 	 partial train loss (single batch): 0.031934
# 	 partial train loss (single batch): 0.030788
# 	 partial train loss (single batch): 0.029887
# 	 partial train loss (single batch): 0.032000
# 	 partial train loss (single batch): 0.031447
# 	 partial train loss (single batch): 0.033328
# 	 partial train loss (single batch): 0.032841
# 	 partial train loss (single batch): 0.033776
# 	 partial train loss (single batch): 0.032775
# 	 partial train loss (single batch): 0.031360
# 	 partial train loss (single batch): 0.032592
# 	 partial train loss (single batch): 0.031440
# 	 partial train loss (single batch): 0.031436
# 	 partial train loss (single batch): 0.032850
# 	 partial train loss (single batch): 0.030223
# 	 partial train loss (single batch): 0.030600
# 	 partial train loss (single batch): 0.033841
# 	 partial train loss (single batch): 0.031105
# 	 partial train loss (single batch): 0.031399
# 	 partial train loss (single batch): 0.032367
# 	 partial train loss (single batch): 0.030111
# 	 partial train loss (single batch): 0.033860
# 	 partial train loss (single batch): 0.034007
# 	 partial train loss (single batch): 0.033139
# 	 partial train loss (single batch): 0.032403
# 	 partial train loss (single batch): 0.031534
# 	 partial train loss (single batch): 0.033535
# 	 partial train loss (single batch): 0.029156
# 	 partial train loss (single batch): 0.032550
# 	 partial train loss (single batch): 0.030416
# 	 partial train loss (single batch): 0.032749
# 	 partial train loss (single batch): 0.030216
#
#  EPOCH 5/30 	 train loss 0.033 	 val loss 0.032
# 	 partial train loss (single batch): 0.032017
# 	 partial train loss (single batch): 0.030111
# 	 partial train loss (single batch): 0.031971
# 	 partial train loss (single batch): 0.032126
# 	 partial train loss (single batch): 0.032220
# 	 partial train loss (single batch): 0.032734
# 	 partial train loss (single batch): 0.033093
# 	 partial train loss (single batch): 0.030521
# 	 partial train loss (single batch): 0.032011
# 	 partial train loss (single batch): 0.031456
# 	 partial train loss (single batch): 0.030257
# 	 partial train loss (single batch): 0.031536
# 	 partial train loss (single batch): 0.031813
# 	 partial train loss (single batch): 0.032493
# 	 partial train loss (single batch): 0.030560
# 	 partial train loss (single batch): 0.031432
# 	 partial train loss (single batch): 0.030756
# 	 partial train loss (single batch): 0.032161
# 	 partial train loss (single batch): 0.030339
# 	 partial train loss (single batch): 0.032138
# 	 partial train loss (single batch): 0.031438
# 	 partial train loss (single batch): 0.031332
# 	 partial train loss (single batch): 0.031678
# 	 partial train loss (single batch): 0.032828
# 	 partial train loss (single batch): 0.032207
# 	 partial train loss (single batch): 0.030219
# 	 partial train loss (single batch): 0.030077
# 	 partial train loss (single batch): 0.031737
# 	 partial train loss (single batch): 0.031924
# 	 partial train loss (single batch): 0.030916
# 	 partial train loss (single batch): 0.032314
# 	 partial train loss (single batch): 0.032181
# 	 partial train loss (single batch): 0.032421
# 	 partial train loss (single batch): 0.032039
# 	 partial train loss (single batch): 0.032910
# 	 partial train loss (single batch): 0.032846
# 	 partial train loss (single batch): 0.032173
# 	 partial train loss (single batch): 0.032916
# 	 partial train loss (single batch): 0.032397
# 	 partial train loss (single batch): 0.031615
# 	 partial train loss (single batch): 0.030715
# 	 partial train loss (single batch): 0.031347
# 	 partial train loss (single batch): 0.030976
# 	 partial train loss (single batch): 0.031515
# 	 partial train loss (single batch): 0.030567
# 	 partial train loss (single batch): 0.032227
# 	 partial train loss (single batch): 0.029482
# 	 partial train loss (single batch): 0.029988
# 	 partial train loss (single batch): 0.030469
# 	 partial train loss (single batch): 0.030979
# 	 partial train loss (single batch): 0.032480
# 	 partial train loss (single batch): 0.031857
# 	 partial train loss (single batch): 0.032330
# 	 partial train loss (single batch): 0.031829
# 	 partial train loss (single batch): 0.031796
# 	 partial train loss (single batch): 0.030339
# 	 partial train loss (single batch): 0.032506
# 	 partial train loss (single batch): 0.030871
# 	 partial train loss (single batch): 0.031854
# 	 partial train loss (single batch): 0.031102
# 	 partial train loss (single batch): 0.031666
# 	 partial train loss (single batch): 0.031289
# 	 partial train loss (single batch): 0.030945
# 	 partial train loss (single batch): 0.031750
# 	 partial train loss (single batch): 0.032159
# 	 partial train loss (single batch): 0.031680
# 	 partial train loss (single batch): 0.032057
# 	 partial train loss (single batch): 0.031695
# 	 partial train loss (single batch): 0.031466
# 	 partial train loss (single batch): 0.030441
# 	 partial train loss (single batch): 0.031566
# 	 partial train loss (single batch): 0.030547
# 	 partial train loss (single batch): 0.029097
# 	 partial train loss (single batch): 0.029771
# 	 partial train loss (single batch): 0.031057
# 	 partial train loss (single batch): 0.032328
# 	 partial train loss (single batch): 0.030639
# 	 partial train loss (single batch): 0.030479
# 	 partial train loss (single batch): 0.030565
# 	 partial train loss (single batch): 0.030616
# 	 partial train loss (single batch): 0.031722
# 	 partial train loss (single batch): 0.029436
# 	 partial train loss (single batch): 0.032478
# 	 partial train loss (single batch): 0.030912
# 	 partial train loss (single batch): 0.032528
# 	 partial train loss (single batch): 0.030848
# 	 partial train loss (single batch): 0.032721
# 	 partial train loss (single batch): 0.031515
# 	 partial train loss (single batch): 0.032097
# 	 partial train loss (single batch): 0.030779
# 	 partial train loss (single batch): 0.032133
# 	 partial train loss (single batch): 0.031733
# 	 partial train loss (single batch): 0.030808
# 	 partial train loss (single batch): 0.030788
# 	 partial train loss (single batch): 0.031209
# 	 partial train loss (single batch): 0.029292
# 	 partial train loss (single batch): 0.030835
# 	 partial train loss (single batch): 0.032814
# ...
# 	 partial train loss (single batch): 0.026695
# 	 partial train loss (single batch): 0.026731
# 	 partial train loss (single batch): 0.025898
# 	 partial train loss (single batch): 0.027567
# 	 partial train loss (single batch): 0.027962
# 	 partial train loss (single batch): 0.026857
# 	 partial train loss (single batch): 0.027878
# 	 partial train loss (single batch): 0.027007
# 	 partial train loss (single batch): 0.026183
# 	 partial train loss (single batch): 0.025744
# 	 partial train loss (single batch): 0.026096
# 	 partial train loss (single batch): 0.026067
# 	 partial train loss (single batch): 0.026506
# 	 partial train loss (single batch): 0.024995
# 	 partial train loss (single batch): 0.027004
# 	 partial train loss (single batch): 0.024309
# 	 partial train loss (single batch): 0.024537
# 	 partial train loss (single batch): 0.025080
# 	 partial train loss (single batch): 0.025534
# 	 partial train loss (single batch): 0.027907
# 	 partial train loss (single batch): 0.026352
# 	 partial train loss (single batch): 0.027636
# 	 partial train loss (single batch): 0.026362
# 	 partial train loss (single batch): 0.026409
# 	 partial train loss (single batch): 0.025211
# 	 partial train loss (single batch): 0.026933
# 	 partial train loss (single batch): 0.024891
# 	 partial train loss (single batch): 0.026587
# 	 partial train loss (single batch): 0.026304
# 	 partial train loss (single batch): 0.026570
# 	 partial train loss (single batch): 0.026715
# 	 partial train loss (single batch): 0.025710
# 	 partial train loss (single batch): 0.026521
# 	 partial train loss (single batch): 0.026397
# 	 partial train loss (single batch): 0.026737
# 	 partial train loss (single batch): 0.027095
# 	 partial train loss (single batch): 0.026404
# 	 partial train loss (single batch): 0.026537
# 	 partial train loss (single batch): 0.025520
# 	 partial train loss (single batch): 0.025679
# 	 partial train loss (single batch): 0.025546
# 	 partial train loss (single batch): 0.023768
# 	 partial train loss (single batch): 0.024890
# 	 partial train loss (single batch): 0.026052
# 	 partial train loss (single batch): 0.027623
# 	 partial train loss (single batch): 0.025504
# 	 partial train loss (single batch): 0.025142
# 	 partial train loss (single batch): 0.025910
# 	 partial train loss (single batch): 0.025581
# 	 partial train loss (single batch): 0.026480
# 	 partial train loss (single batch): 0.024454
# 	 partial train loss (single batch): 0.026785
# 	 partial train loss (single batch): 0.026286
# 	 partial train loss (single batch): 0.026994
# 	 partial train loss (single batch): 0.025573
# 	 partial train loss (single batch): 0.027843
# 	 partial train loss (single batch): 0.026038
# 	 partial train loss (single batch): 0.027248
# 	 partial train loss (single batch): 0.026544
# 	 partial train loss (single batch): 0.027484
# 	 partial train loss (single batch): 0.026639
# 	 partial train loss (single batch): 0.025820
# 	 partial train loss (single batch): 0.026057
# 	 partial train loss (single batch): 0.026063
# 	 partial train loss (single batch): 0.024248
# 	 partial train loss (single batch): 0.025930
# 	 partial train loss (single batch): 0.027581
# 	 partial train loss (single batch): 0.026698
# 	 partial train loss (single batch): 0.026369
# 	 partial train loss (single batch): 0.025269
# 	 partial train loss (single batch): 0.026868
# 	 partial train loss (single batch): 0.025989
# 	 partial train loss (single batch): 0.026697
# 	 partial train loss (single batch): 0.025983
# 	 partial train loss (single batch): 0.026432
# 	 partial train loss (single batch): 0.026944
# 	 partial train loss (single batch): 0.027090
# 	 partial train loss (single batch): 0.025180
# 	 partial train loss (single batch): 0.025523
# 	 partial train loss (single batch): 0.024623
# 	 partial train loss (single batch): 0.026012
# 	 partial train loss (single batch): 0.027970
# 	 partial train loss (single batch): 0.025304
# 	 partial train loss (single batch): 0.026833
# 	 partial train loss (single batch): 0.026252
# 	 partial train loss (single batch): 0.024925
# 	 partial train loss (single batch): 0.024898
# 	 partial train loss (single batch): 0.027501
# 	 partial train loss (single batch): 0.026722
# 	 partial train loss (single batch): 0.027287
# 	 partial train loss (single batch): 0.026272
# 	 partial train loss (single batch): 0.026937
# 	 partial train loss (single batch): 0.027508
# 	 partial train loss (single batch): 0.027576
# 	 partial train loss (single batch): 0.025793
# 	 partial train loss (single batch): 0.027704
# 	 partial train loss (single batch): 0.024956
# 	 partial train loss (single batch): 0.025881
# 	 partial train loss (single batch): 0.025461
# 	 partial train loss (single batch): 0.024790
# 	 partial train loss (single batch): 0.025262
# 	 partial train loss (single batch): 0.025447
# 	 partial train loss (single batch): 0.025534
# 	 partial train loss (single batch): 0.025993
# 	 partial train loss (single batch): 0.024459
# 	 partial train loss (single batch): 0.026152
# 	 partial train loss (single batch): 0.026128
# 	 partial train loss (single batch): 0.025168
# 	 partial train loss (single batch): 0.025731
# 	 partial train loss (single batch): 0.027302
# 	 partial train loss (single batch): 0.026063
# 	 partial train loss (single batch): 0.026054
# 	 partial train loss (single batch): 0.026169
# 	 partial train loss (single batch): 0.026799
# 	 partial train loss (single batch): 0.026941
# 	 partial train loss (single batch): 0.025246
# 	 partial train loss (single batch): 0.024755
# 	 partial train loss (single batch): 0.025298
# 	 partial train loss (single batch): 0.026113
# 	 partial train loss (single batch): 0.025932
# 	 partial train loss (single batch): 0.025917
# 	 partial train loss (single batch): 0.026318
# 	 partial train loss (single batch): 0.024743
# 	 partial train loss (single batch): 0.026350
# 	 partial train loss (single batch): 0.025452
# 	 partial train loss (single batch): 0.025686
# 	 partial train loss (single batch): 0.025020
# 	 partial train loss (single batch): 0.024077
# 	 partial train loss (single batch): 0.026036
# 	 partial train loss (single batch): 0.026532
# 	 partial train loss (single batch): 0.027406
# 	 partial train loss (single batch): 0.027138
# 	 partial train loss (single batch): 0.027784
# 	 partial train loss (single batch): 0.026738
# 	 partial train loss (single batch): 0.025971
# 	 partial train loss (single batch): 0.026859
# 	 partial train loss (single batch): 0.025303
# 	 partial train loss (single batch): 0.025304
# 	 partial train loss (single batch): 0.026727
# 	 partial train loss (single batch): 0.024692
# 	 partial train loss (single batch): 0.024565
# 	 partial train loss (single batch): 0.027222
# 	 partial train loss (single batch): 0.025641
# 	 partial train loss (single batch): 0.025624
# 	 partial train loss (single batch): 0.026706
# 	 partial train loss (single batch): 0.024552
# 	 partial train loss (single batch): 0.027723
# 	 partial train loss (single batch): 0.028439
# 	 partial train loss (single batch): 0.027430
# 	 partial train loss (single batch): 0.026628
# 	 partial train loss (single batch): 0.026209
# 	 partial train loss (single batch): 0.026998
# 	 partial train loss (single batch): 0.023734
# 	 partial train loss (single batch): 0.026698
# 	 partial train loss (single batch): 0.024739
# 	 partial train loss (single batch): 0.026984
# 	 partial train loss (single batch): 0.024026
#
#  EPOCH 29/30 	 train loss 0.026 	 val loss 0.027
# 	 partial train loss (single batch): 0.026578
# 	 partial train loss (single batch): 0.024303
# 	 partial train loss (single batch): 0.026437
# 	 partial train loss (single batch): 0.026713
# 	 partial train loss (single batch): 0.026494
# 	 partial train loss (single batch): 0.026662
# 	 partial train loss (single batch): 0.027503
# 	 partial train loss (single batch): 0.025526
# 	 partial train loss (single batch): 0.026806
# 	 partial train loss (single batch): 0.026416
# 	 partial train loss (single batch): 0.024421
# 	 partial train loss (single batch): 0.025679
# 	 partial train loss (single batch): 0.025941
# 	 partial train loss (single batch): 0.026662
# 	 partial train loss (single batch): 0.025394
# 	 partial train loss (single batch): 0.026207
# 	 partial train loss (single batch): 0.025189
# 	 partial train loss (single batch): 0.026229
# 	 partial train loss (single batch): 0.024566
# 	 partial train loss (single batch): 0.026933
# 	 partial train loss (single batch): 0.026209
# 	 partial train loss (single batch): 0.025737
# 	 partial train loss (single batch): 0.026086
# 	 partial train loss (single batch): 0.027179
# 	 partial train loss (single batch): 0.026611
# 	 partial train loss (single batch): 0.024757
# 	 partial train loss (single batch): 0.024764
# 	 partial train loss (single batch): 0.026193
# 	 partial train loss (single batch): 0.026998
# 	 partial train loss (single batch): 0.025165
# 	 partial train loss (single batch): 0.026846
# 	 partial train loss (single batch): 0.026695
# 	 partial train loss (single batch): 0.026651
# 	 partial train loss (single batch): 0.025867
# 	 partial train loss (single batch): 0.027549
# 	 partial train loss (single batch): 0.028002
# 	 partial train loss (single batch): 0.026845
# 	 partial train loss (single batch): 0.027856
# 	 partial train loss (single batch): 0.026876
# 	 partial train loss (single batch): 0.026112
# 	 partial train loss (single batch): 0.025638
# 	 partial train loss (single batch): 0.026045
# 	 partial train loss (single batch): 0.026098
# 	 partial train loss (single batch): 0.026482
# 	 partial train loss (single batch): 0.024917
# 	 partial train loss (single batch): 0.027022
# 	 partial train loss (single batch): 0.024290
# 	 partial train loss (single batch): 0.024507
# 	 partial train loss (single batch): 0.025081
# 	 partial train loss (single batch): 0.025462
# 	 partial train loss (single batch): 0.027860
# 	 partial train loss (single batch): 0.026306
# 	 partial train loss (single batch): 0.027558
# 	 partial train loss (single batch): 0.026311
# 	 partial train loss (single batch): 0.026339
# 	 partial train loss (single batch): 0.025176
# 	 partial train loss (single batch): 0.026889
# 	 partial train loss (single batch): 0.024846
# 	 partial train loss (single batch): 0.026567
# 	 partial train loss (single batch): 0.026265
# 	 partial train loss (single batch): 0.026474
# 	 partial train loss (single batch): 0.026634
# 	 partial train loss (single batch): 0.025641
# 	 partial train loss (single batch): 0.026463
# 	 partial train loss (single batch): 0.026328
# 	 partial train loss (single batch): 0.026701
# 	 partial train loss (single batch): 0.027018
# 	 partial train loss (single batch): 0.026314
# 	 partial train loss (single batch): 0.026532
# 	 partial train loss (single batch): 0.025438
# 	 partial train loss (single batch): 0.025607
# 	 partial train loss (single batch): 0.025519
# 	 partial train loss (single batch): 0.023672
# 	 partial train loss (single batch): 0.024811
# 	 partial train loss (single batch): 0.026039
# 	 partial train loss (single batch): 0.027517
# 	 partial train loss (single batch): 0.025418
# 	 partial train loss (single batch): 0.025058
# 	 partial train loss (single batch): 0.025764
# 	 partial train loss (single batch): 0.025518
# 	 partial train loss (single batch): 0.026448
# 	 partial train loss (single batch): 0.024402
# 	 partial train loss (single batch): 0.026647
# 	 partial train loss (single batch): 0.026164
# 	 partial train loss (single batch): 0.026994
# 	 partial train loss (single batch): 0.025522
# 	 partial train loss (single batch): 0.027704
# 	 partial train loss (single batch): 0.025985
# 	 partial train loss (single batch): 0.027270
# 	 partial train loss (single batch): 0.026449
# 	 partial train loss (single batch): 0.027404
# 	 partial train loss (single batch): 0.026664
# 	 partial train loss (single batch): 0.025740
# 	 partial train loss (single batch): 0.026049
# 	 partial train loss (single batch): 0.025949
# 	 partial train loss (single batch): 0.024228
# 	 partial train loss (single batch): 0.025837
# 	 partial train loss (single batch): 0.027528
# 	 partial train loss (single batch): 0.026600
# 	 partial train loss (single batch): 0.026319
# 	 partial train loss (single batch): 0.025112
# 	 partial train loss (single batch): 0.026789
# 	 partial train loss (single batch): 0.025886
# 	 partial train loss (single batch): 0.026647
# 	 partial train loss (single batch): 0.025942
# 	 partial train loss (single batch): 0.026362
# 	 partial train loss (single batch): 0.026745
# 	 partial train loss (single batch): 0.026997
# 	 partial train loss (single batch): 0.025061
# 	 partial train loss (single batch): 0.025428
# 	 partial train loss (single batch): 0.024488
# 	 partial train loss (single batch): 0.025963
# 	 partial train loss (single batch): 0.027787
# 	 partial train loss (single batch): 0.025280
# 	 partial train loss (single batch): 0.026791
# 	 partial train loss (single batch): 0.026175
# 	 partial train loss (single batch): 0.024843
# 	 partial train loss (single batch): 0.024818
# 	 partial train loss (single batch): 0.027464
# 	 partial train loss (single batch): 0.026672
# 	 partial train loss (single batch): 0.027173
# 	 partial train loss (single batch): 0.026250
# 	 partial train loss (single batch): 0.026886
# 	 partial train loss (single batch): 0.027472
# 	 partial train loss (single batch): 0.027577
# 	 partial train loss (single batch): 0.025791
# 	 partial train loss (single batch): 0.027594
# 	 partial train loss (single batch): 0.024948
# 	 partial train loss (single batch): 0.025687
# 	 partial train loss (single batch): 0.025384
# 	 partial train loss (single batch): 0.024721
# 	 partial train loss (single batch): 0.025190
# 	 partial train loss (single batch): 0.025340
# 	 partial train loss (single batch): 0.025488
# 	 partial train loss (single batch): 0.025886
# 	 partial train loss (single batch): 0.024406
# 	 partial train loss (single batch): 0.026151
# 	 partial train loss (single batch): 0.026061
# 	 partial train loss (single batch): 0.025102
# 	 partial train loss (single batch): 0.025702
# 	 partial train loss (single batch): 0.027242
# 	 partial train loss (single batch): 0.025986
# 	 partial train loss (single batch): 0.025964
# 	 partial train loss (single batch): 0.026186
# 	 partial train loss (single batch): 0.026724
# 	 partial train loss (single batch): 0.026901
# 	 partial train loss (single batch): 0.025182
# 	 partial train loss (single batch): 0.024646
# 	 partial train loss (single batch): 0.025260
# 	 partial train loss (single batch): 0.026075
# 	 partial train loss (single batch): 0.025820
# 	 partial train loss (single batch): 0.025866
# 	 partial train loss (single batch): 0.026207
# 	 partial train loss (single batch): 0.024662
# 	 partial train loss (single batch): 0.026324
# 	 partial train loss (single batch): 0.025447
# 	 partial train loss (single batch): 0.025653
# 	 partial train loss (single batch): 0.025020
# 	 partial train loss (single batch): 0.023925
# 	 partial train loss (single batch): 0.025940
# 	 partial train loss (single batch): 0.026422
# 	 partial train loss (single batch): 0.027298
# 	 partial train loss (single batch): 0.027061
# 	 partial train loss (single batch): 0.027658
# 	 partial train loss (single batch): 0.026653
# 	 partial train loss (single batch): 0.025888
# 	 partial train loss (single batch): 0.026757
# 	 partial train loss (single batch): 0.025213
# 	 partial train loss (single batch): 0.025214
# 	 partial train loss (single batch): 0.026653
# 	 partial train loss (single batch): 0.024562
# 	 partial train loss (single batch): 0.024471
# 	 partial train loss (single batch): 0.027045
# 	 partial train loss (single batch): 0.025525
# 	 partial train loss (single batch): 0.025515
# 	 partial train loss (single batch): 0.026678
# 	 partial train loss (single batch): 0.024529
# 	 partial train loss (single batch): 0.027613
# 	 partial train loss (single batch): 0.028357
# 	 partial train loss (single batch): 0.027380
# 	 partial train loss (single batch): 0.026564
# 	 partial train loss (single batch): 0.026234
# 	 partial train loss (single batch): 0.027016
# 	 partial train loss (single batch): 0.023650
# 	 partial train loss (single batch): 0.026676
# 	 partial train loss (single batch): 0.024663
# 	 partial train loss (single batch): 0.026964
# 	 partial train loss (single batch): 0.023952
#
#  EPOCH 30/30 	 train loss 0.026 	 val loss 0.027

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.026823632419109344

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %% [markdown]
# ## 5. Generate new samples from the latent code

# %%
def plot_reconstructed(decoder, r0=(-5, 10), r1=(-10, 5), n=10):
    plt.figure(figsize=(20,8.5))
    w = 28
    img = np.zeros((n*w, n*w))
    for i, y in enumerate(np.linspace(*r1, n)):
        for j, x in enumerate(np.linspace(*r0, n)):
            z = torch.Tensor([[x, y]]).to(device)
            x_hat = decoder(z)
            x_hat = x_hat.reshape(28, 28).to('cpu').detach().numpy()
            img[(n-1-i)*w:(n-1-i+1)*w, j*w:(j+1)*w] = x_hat
    plt.imshow(img, extent=[*r0, *r1], cmap='gist_gray')

# %%
plot_reconstructed(decoder, r0=(-1, 1), r1=(-1, 1))

# %% [markdown]
# ## 6. Visualize Latent Code

# %%
encoded_samples = []
for sample in tqdm(test_dataset):
    img = sample[0].unsqueeze(0).to(device)
    label = sample[1]
    # Encode image
    encoder.eval()
    with torch.no_grad():
        encoded_img  = encoder(img)
    # Append to list
    encoded_img = encoded_img.flatten().cpu().numpy()
    encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
    encoded_sample['label'] = label
    encoded_samples.append(encoded_sample)
# Out:
# 100%|██████████| 10000/10000 [00:09<00:00, 1022.08it/s]

# %%
encoded_samples = pd.DataFrame(encoded_samples)
encoded_samples
# Out:
#       Enc. Variable 0  Enc. Variable 1  Enc. Variable 2  Enc. Variable 3  label
# 0           -2.268883         1.364354        -0.324822         0.579734      7
# 1            0.454310         0.688136         1.843909         0.363326      2
# 2            0.228852         1.283970        -0.108525         0.698502      1
# 3           -0.180028        -0.964370         0.466799        -0.232247      0
# 4           -0.556886        -0.119552        -0.489528        -0.667211      4
# ...               ...              ...              ...              ...    ...
# 9995        -0.898000         0.782184         2.056643         1.685823      2
# 9996         0.931687         0.013393         1.044017        -0.456957      3
# 9997        -0.570510         0.108823        -0.769197         0.052889      4
# 9998         0.876379        -0.858239        -1.020191         0.321995      5
# 9999        -0.369772        -0.775070         0.777947        -0.107602      6
#
# [10000 rows x 5 columns]

# %%
px.scatter(encoded_samples, x='Enc. Variable 0', y='Enc. Variable 1', color=encoded_samples.label.astype(str), opacity=0.7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ab1f8bd8-1c9a-4a8e-8203-373952dbaddf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ab1f8bd8-1c9a-4a8e-8203-373952dbaddf")) {
#                     Plotly.newPlot(
#                         'ab1f8bd8-1c9a-4a8e-8203-373952dbaddf',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "color=7<br>Enc. Variable 0=%{x}<br>Enc. Variable 1=%{y}", "legendgroup": "color=7", "marker": {"color": "#636efa", "opacity": 0.7, "symbol": "circle"}, "mode": "markers", "name": "color=7", "showlegend": true, "type": "scattergl", "x": [-2.2688825130462646, -2.643390417098999, -2.118701457977295, -1.262058973312378, -1.6765819787979126, -1.2567275762557983, -2.2259724140167236, -1.0127958059310913, -2.8708889484405518, -0.6160194277763367, -1.1994014978408813, -0.8613366484642029, -1.1751738786697388, -0.8407002687454224, -0.3863540589809418, -0.3770580589771271, -0.5359943509101868, -1.5253429412841797, -1.43175208568573, -1.086475133895874, -2.1560261249542236, -0.6778973340988159, -0.6512849926948547, -0.5198134779930115, -0.9867273569107056, -1.395825743675232, -1.5603400468826294, -1.3289892673492432, -0.657256543636322, -1.790441632270813, -1.0774660110473633, -1.7284177541732788, -1.052742600440979, -0.5229076743125916, -0.6673486232757568, -0.4831148087978363, -0.5541369318962097, -1.8763662576675415, -1.0033485889434814, -1.3025779724121094, -1.9742107391357422, -1.6671967506408691, -0.5183276534080505, -1.5550148487091064, -1.6043609380722046, -1.5782055854797363, -0.5589011311531067, -2.718240737915039, -1.7445298433303833, -0.9084107875823975, -1.0908151865005493, -0.7728810906410217, -0.05752750113606453, -1.2309374809265137, -0.7528188824653625, -1.0259615182876587, -1.6922141313552856, -0.3157879710197449, -0.8335812091827393, -1.4699474573135376, -3.037074089050293, -1.526175618171692, -1.1464409828186035, -1.4775422811508179, -0.7956928610801697, -0.5481841564178467, -1.7171344757080078, -1.0896716117858887, -0.16308388113975525, -0.7536613345146179, -0.8938888907432556, -0.8032767176628113, -1.3592435121536255, -0.6025148034095764, -1.7378195524215698, -0.9579656720161438, -1.4887083768844604, -0.8718381524085999, -1.1852205991744995, -2.7117435932159424, -1.2276804447174072, -0.6334195137023926, -1.2681034803390503, -1.3585630655288696, -0.7963459491729736, -2.1890716552734375, -0.7147347331047058, -0.790087103843689, -1.4737563133239746, -0.2220248579978943, -2.5330774784088135, -1.2601277828216553, -1.7169575691223145, -0.12567046284675598, -1.843827486038208, -1.1253172159194946, -0.5101411938667297, -0.28933247923851013, -0.7859511375427246, -1.1029365062713623, -0.3794173002243042, -2.1090543270111084, 0.011712875217199326, -0.9021110534667969, -1.189941167831421, -0.46468257904052734, -1.1690287590026855, -1.1552711725234985, -1.7507158517837524, -2.8132314682006836, -0.6921471953392029, -0.36589422821998596, -1.6453001499176025, -1.955387830734253, -0.9064481258392334, -1.1621462106704712, -0.48019737005233765, -0.16399367153644562, -0.9573947191238403, -1.2288557291030884, -0.5148082971572876, -1.1403796672821045, -2.2618002891540527, -0.5202478766441345, -0.4693390429019928, -0.9470956921577454, -0.3511011600494385, -0.8309173583984375, -0.7562450170516968, 0.005499064922332764, -0.9725394248962402, -0.3730385899543762, -1.3320984840393066, -0.5935800075531006, -0.5148205161094666, -1.674780011177063, -1.09512197971344, -0.6965336799621582, -1.4960771799087524, -0.9102070331573486, -0.8352124094963074, -1.5307525396347046, -2.380838394165039, -1.4632545709609985, -1.0124537944793701, -0.6525586843490601, -0.479650616645813, -0.7370638847351074, -2.346975564956665, -1.4382376670837402, 0.221586212515831, -0.9138182997703552, -0.9566038846969604, -1.3380178213119507, -0.3963416814804077, -2.445079803466797, -1.0318862199783325, -1.6907615661621094, -1.0356109142303467, -1.202452540397644, -0.8077380657196045, -1.6053788661956787, -0.42533358931541443, -0.8228498697280884, -1.9259206056594849, -0.9503324627876282, -1.0870274305343628, -0.8326549530029297, -0.8892382979393005, -2.1765756607055664, -1.6601563692092896, -1.3211219310760498, -1.2295852899551392, -0.5681966543197632, -0.7409990429878235, -0.49424588680267334, -1.99 ...

# %%
plt.figure(figsize=(17, 9))
plt.scatter(encoded_samples['Enc. Variable 0'], encoded_samples['Enc. Variable 1'], c=encoded_samples.label, cmap='tab10')
plt.colorbar()
plt.show()

# %%
pca = PCA(n_components=2)
components = pca.fit_transform(encoded_samples.drop(['label'],axis=1))
total_var = pca.explained_variance_ratio_.sum() * 100
print(total_var)
# Out:
# 62.58848624383147

# %%
fig = px.scatter(components, x=0, y=1, color=encoded_samples.label.astype(str),labels={'0': 'PC 1', '1': 'PC 2'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80d61261-7a97-4aa8-9c32-803804db53d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80d61261-7a97-4aa8-9c32-803804db53d8")) {
#                     Plotly.newPlot(
#                         '80d61261-7a97-4aa8-9c32-803804db53d8',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "color=7<br>PC 1=%{x}<br>PC 2=%{y}", "legendgroup": "color=7", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "color=7", "showlegend": true, "type": "scattergl", "x": [2.551006556601506, 2.7425143511926513, 2.1764293225059492, 1.5185409464773578, 1.9176742405030232, 1.565548631248949, 2.1199464409705704, 0.8287081155927537, 2.7775980563441185, 0.7790781622755489, 1.0196396126389906, 0.8743559998863933, 1.2375574273733745, 0.9355333148951896, 0.521411960074219, 0.802674757267562, 0.7223831787015631, 2.104069240126064, 1.1520373322611437, 0.9053250744603996, 2.310674324982158, 0.5910549475976138, 0.5816073079224278, 1.6349698615144719, 0.870794043491883, 1.5604099493835213, 2.1824937340339767, 1.9341134556864585, 0.8040363342389316, 2.191293466359729, 1.51340298277693, 1.9658620705261582, 1.4002601812288211, 0.7245964777101497, 0.6050257767458257, 0.6656951329748251, 0.7020901465970588, 2.05786397876627, 1.2581201382209088, 1.6490513754652616, 2.6959295194072306, 1.7427300807060122, 0.9704838676694373, 1.3350042613504052, 1.5605137295913638, 1.7737660200709342, 0.5135799110279472, 2.736213377224362, 1.7959579055035526, 0.8977034734698857, 0.9407900606959986, 1.1527609391861457, 0.3536622809619024, 1.4028496870215748, 0.8673936298182509, 1.0395507045073675, 1.9637911405557897, 0.5487005570445865, 0.8589440414979069, 1.7049457637400642, 2.8396642972602137, 2.0592578833789363, 1.0608725635764316, 0.9732559743644642, 1.1588517282410715, 1.5692176556811361, 1.618313693672192, 1.5524753673734983, 0.20387434442208804, 0.9929982685225032, 1.1682401130137416, 0.9046645251171073, 1.6207528022047302, 1.1471519250960254, 1.231466514479569, 1.212006037564453, 1.835086976278444, 0.7634867098521486, 0.9557434854990433, 2.208737331259376, 1.3084507918920278, 0.95465594245081, 0.8364511290183634, 2.141549496823607, 0.5074993075036289, 2.5430153802518363, 1.0549601559307378, 1.0378446380812174, 1.8650882879607606, 0.4030547330914439, 2.283125823552382, 1.474889459019651, 2.0770183876794235, 0.4155466443587644, 2.0103784479997096, 1.5858461994631419, 0.5931815430257952, 0.6790952211580136, 0.9306882690286629, 1.2632760198326833, 0.467739354616875, 1.9492714671051647, 0.4119609000055474, 0.9000318814204878, 1.295951301540548, 0.542640309954629, 0.7151143843825174, 1.1341599517054022, 2.2967078531057235, 3.0306984156913197, 1.2094309625343789, 0.22956771325914715, 2.50303657850348, 1.643990802333675, 1.1529221644535472, 1.480262204160144, 0.3468248550393848, 0.2608259702497255, 0.7167738923984659, 1.5798771523431396, 0.5342270644381014, 1.3671105310485983, 1.8772767811586117, 0.37003635835567555, 0.823246726879353, 1.5054504802328534, 0.4838269224230533, 0.8825608373320628, 0.9710568764180083, 1.0599722212470282, 0.8329819726789882, 0.6680813718424277, 1.636686575168497, 1.3184577484793971, 0.39582521660081577, 2.0654177992250076, 1.0084859102511592, 0.9087213503325875, 2.0300422715032775, 1.4490202208324865, 1.0704906218828436, 1.883709957324689, 2.5603883421357714, 1.192413806793175, 1.0948524167814147, 0.6802092528998667, 0.17950673007221102, 0.8938525132485783, 2.080186768427692, 1.2600987755748545, 0.5198865845849994, 1.5033831934227824, 1.4886995574063857, 0.9182839513233916, 0.6517462012594496, 2.2386980392344933, 0.7880838323486601, 2.0600969837703884, 1.2073464076683431, 1.5409839745533715, 1.2042108772576867, 2.042168486374594, 0.42236779217418274, 1.0319693620695107, 2.4291810266204257, 0.8587461699329716, 1.3422129063305874, 1.5859218243109985, 0.8995138382446959, 2.3937792689130295, 2.584057724547513, 1.6955596747681423, 1.4905534910354397, 1.5978750625664793, 0.616492229599508, 0.6907425587125029, 1.3867715354103742, 0.8905748811867518, 1.3112307320201495, 0.5872970194557604, 1.838272591184157, 1.362441980771338, 1.8351007464876326, 1.2054822809078292, 2.096292412964399, 1.0441029246723303, 1.6642464672201573, 2.3360436359019077, ...

# %%
plt.figure(figsize=(17, 9))
plt.scatter(components[:,0], components[:,1], c=encoded_samples.label, cmap='tab10')
plt.colorbar()
plt.show()

# %%
tsne = TSNE(n_components=2)
tsne_results = tsne.fit_transform(encoded_samples.drop(['label'],axis=1))

# %%
fig = px.scatter(tsne_results, x=0, y=1, color=encoded_samples.label.astype(str),labels={'0': 'tsne-2d-one', '1': 'tsne-2d-two'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ba84dd8-d4af-4469-b5d3-f4bab2f82854" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ba84dd8-d4af-4469-b5d3-f4bab2f82854")) {
#                     Plotly.newPlot(
#                         '4ba84dd8-d4af-4469-b5d3-f4bab2f82854',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "color=7<br>tsne-2d-one=%{x}<br>tsne-2d-two=%{y}", "legendgroup": "color=7", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "color=7", "showlegend": true, "type": "scattergl", "x": [19.108474731445312, 19.729759216308594, 30.910507202148438, 10.32888126373291, 22.375154495239258, 20.445703506469727, 27.937376022338867, 19.932546615600586, 20.0508975982666, 35.936805725097656, 21.25506019592285, 66.78797149658203, 34.920169830322266, 29.977190017700195, 34.54049301147461, 27.757553100585938, 35.195579528808594, 25.09625244140625, 28.57583236694336, 35.6822624206543, 28.99668312072754, 31.132457733154297, 11.12198257446289, 6.218441486358643, 35.04645538330078, 15.982026100158691, 20.112245559692383, 19.685697555541992, 38.075157165527344, 23.778806686401367, 25.40189552307129, 27.618993759155273, 23.276824951171875, 35.14409255981445, 37.02761459350586, 35.12925720214844, 35.30579376220703, 22.030824661254883, 69.21351623535156, 25.749645233154297, 19.606786727905273, 28.608673095703125, 28.26164436340332, 34.718021392822266, 32.32697296142578, 28.153690338134766, 11.184683799743652, 28.432825088500977, 18.623523712158203, 12.095891952514648, 37.772247314453125, 29.43051528930664, -28.273406982421875, 18.419334411621094, 37.969947814941406, 20.276721954345703, 25.401683807373047, 12.941893577575684, 33.74357986450195, 14.905964851379395, 32.7247200012207, 25.062837600708008, 36.28716278076172, 28.98619270324707, 26.261423110961914, 6.191463470458984, 15.762903213500977, 25.052167892456055, 58.95766067504883, 35.29948425292969, 30.36518669128418, 38.152000427246094, 28.033039093017578, 67.3261947631836, 34.099510192871094, 28.690898895263672, 18.340559005737305, 55.22526168823242, 35.402976989746094, 33.89054870605469, 30.785390853881836, 32.21697235107422, 36.96510696411133, 17.832109451293945, 15.053791046142578, 28.900516510009766, 10.169620513916016, 32.87849044799805, 10.265007972717285, 33.72690963745117, 31.890750885009766, 13.231417655944824, 27.70232582092285, -28.151763916015625, 22.27975082397461, 25.846956253051758, 52.26334762573242, 16.18358039855957, 32.730648040771484, 29.88921356201172, 55.548011779785156, 33.23189163208008, 61.40304946899414, 31.310840606689453, 32.28141784667969, 36.9399299621582, 49.35586929321289, 23.52330207824707, 17.97408676147461, 20.23573875427246, 8.645319938659668, 8.653209686279297, 19.529521942138672, 30.618486404418945, 26.529956817626953, 25.21523094177246, 29.911020278930664, 55.61715316772461, 50.382572174072266, 27.704444885253906, 21.019533157348633, 28.514629364013672, 32.41840362548828, 12.32339859008789, 49.966644287109375, 27.93111228942871, 58.228675842285156, 9.564521789550781, 33.20646667480469, -42.71198654174805, 36.93913650512695, 49.71445846557617, 26.055688858032227, 5.42726993560791, 31.72962760925293, 28.259960174560547, 34.25220489501953, 6.441718578338623, 19.028270721435547, 11.17304515838623, 38.93661117553711, 26.6987361907959, 19.948102951049805, 16.332014083862305, 33.25651550292969, 36.366920471191406, 39.80208206176758, 64.81754302978516, 32.374839782714844, 23.67167854309082, -22.687332153320312, 24.594072341918945, 11.214753150939941, 14.027379989624023, 61.376060485839844, 32.16270446777344, 33.44704055786133, 26.355182647705078, 25.341127395629883, 21.785301208496094, 35.136661529541016, 20.82571792602539, 11.548959732055664, 33.15475082397461, 18.971282958984375, 34.8817024230957, 23.516151428222656, 8.275066375732422, 70.51057434082031, 23.77542495727539, 17.6020450592041, 26.497943878173828, 21.486268997192383, 7.243224143981934, 37.599220275878906, 45.48276901245117, 32.05692672729492, 27.86043930053711, 29.357690811157227, 58.326473236083984, 11.528376579284668, 32.923439025878906, 18.967023849487305, 34.676292419433594, 20.165546417236328, 33.93833923339844, 25.077852249145508, 31.747180938720703, 19.712921142578125, 29.072036743164062, 1 ...

# %%
plt.figure(figsize=(17, 9))
plt.scatter(tsne_results[:,0], tsne_results[:,1], c=encoded_samples.label, cmap='tab10')
plt.colorbar()
plt.show()
