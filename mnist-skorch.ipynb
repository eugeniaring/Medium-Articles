# %% [markdown]
# ## MNIST with torchvision and skorch

# %% [markdown]
# ## Example with Pytorch

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets,transforms 
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
DEVICE
# Out:
# device(type='cpu')

# %%
train_dataset = torchvision.datasets.MNIST('classifier_data', train=True, download=True)
test_dataset  = torchvision.datasets.MNIST('classifier_data', train=False, download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to classifier_data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting classifier_data/MNIST/raw/train-images-idx3-ubyte.gz to classifier_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to classifier_data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting classifier_data/MNIST/raw/train-labels-idx1-ubyte.gz to classifier_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to classifier_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting classifier_data/MNIST/raw/t10k-images-idx3-ubyte.gz to classifier_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to classifier_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting classifier_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to classifier_data/MNIST/raw
# Processing...
# /opt/conda/lib/python3.7/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729141890/work/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!

# %%
import random

fig, axs = plt.subplots(5, 5, figsize=(8,8))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like object (basically anything that can be accessed with an index, like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
transform = transforms.Compose([
    torchvision.transforms.ToTensor()
])
# Set the train transform
train_dataset.transform = transform
# Set the test transform
test_dataset.transform = transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=64)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64,shuffle=True)

# %%
class ConvNet(nn.Module):
    def __init__(self,dropout_rate=0.4,dropout_rate2=0.2,l1=50):
        # We optimize dropout rate in a convolutional neural network.
        super(ConvNet, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5, stride=1, padding=2)

        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.drop1=nn.Dropout2d(p=dropout_rate)   

        self.fc1 = nn.Linear(32 * 7 * 7, l1)
        self.drop2=nn.Dropout2d(p=dropout_rate2)

        self.fc2 = nn.Linear(l1, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x),kernel_size = 2))

        x = F.relu(F.max_pool2d(self.conv2(x),kernel_size = 2))
        x = self.drop1(x)

        x = x.view(x.size(0),-1)

        x = F.relu(self.fc1(x))
        x = self.drop2(x)

        x = self.fc2(x)

        return x

# %%
model = ConvNet()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

criterion= nn.CrossEntropyLoss()

# %%
valid_loss_min = np.Inf
train_loss_history=[]
val_loss_history=[]
train_acc_history=[]
val_acc_history=[]

num_epochs=10
#dataset_sizes = {'train':len(train_dataset),'val':len(val_dataset),'test':len(test_dataset)}

for epoch in range(num_epochs):
    
    train_loss = 0.0
    train_correct = 0
    
    
    # Training
    model.train()
    for idx, (images, labels) in enumerate(train_loader):
        
        images,labels=images.to(DEVICE),labels.to(DEVICE)
        optimizer.zero_grad() 
        output = model(images).to(DEVICE)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*images.size(0)
        scores, predictions = torch.max(output.data, 1)
        train_correct += (predictions == labels).sum().item()
    
    valid_loss=0.0
    val_correct = 0
    #Validate Model
    model.eval()
    for idx, (images, labels) in enumerate(valid_loader):
        
        images,labels=images.to(DEVICE),labels.to(DEVICE)
        output = model(images).to(DEVICE)
        loss = criterion(output, labels)
        valid_loss += loss.item()*images.size(0)
        scores, predictions = torch.max(output.data, 1)
        val_correct += (predictions == labels).sum().item()
    
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    acc = train_correct/len(train_loader.sampler) * 100
    val_acc = val_correct/len(valid_loader.sampler) * 100
    
    train_loss_history.append(train_loss)
    val_loss_history.append(valid_loss)
    train_acc_history.append(acc)
    val_acc_history.append(val_acc)
    
    print("Epoch:{}/{} \t TL:{:.4f} \t VL:{:.4f} \t TA:{:.2f} %  \t  VA:{:.2f} %".format(epoch+1,num_epochs, 
                                                      train_loss,
                                                      valid_loss,
                                                      acc,
                                                      val_acc))
    
    # Save the best possible model
    if valid_loss < valid_loss_min:
        print("Saving Model")
        torch.save(model.state_dict(), 'MNIST_Weights.pt')
        valid_loss_min = valid_loss

# %% [markdown]
# ## Skorch

# %%
pip install skorch
# Out:
# Collecting skorch
#   Downloading skorch-0.9.0-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from skorch) (1.18.5)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.7/site-packages (from skorch) (0.8.7)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from skorch) (0.23.2)
# Requirement already satisfied: tqdm>=4.14.0 in /opt/conda/lib/python3.7/site-packages (from skorch) (4.45.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from skorch) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from skorch) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.19.1->skorch) (0.14.1)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from skorch) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.19.1->skorch) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from skorch) (1.18.5)
# Installing collected packages: skorch
# Successfully installed skorch-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import skorch
from skorch import NeuralNetClassifier

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets,transforms 

from skorch import NeuralNetClassifier

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class ConvNet(nn.Module):
    def __init__(self,dropout_rate=0.4,dropout_rate2=0.2,l1=50):
        # We optimize dropout rate in a convolutional neural network.
        super(ConvNet, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5, stride=1, padding=2)

        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.drop1=nn.Dropout2d(p=dropout_rate)  
        
        self.fc1 = nn.Linear(32 * 7 * 7, l1)
        self.drop2=nn.Dropout2d(p=dropout_rate2)
        
        self.fc2 = nn.Linear(l1, 10)

    def forward(self, x):
        
        x = F.relu(F.max_pool2d(self.conv1(x),kernel_size = 2))
        
        x = F.relu(F.max_pool2d(self.conv2(x),kernel_size = 2))
        x = self.drop1(x)
        
        x = x.view(x.size(0),-1)
        x = F.relu(self.fc1(x))
        
        x = self.drop2(x)
        x = self.fc2(x)
        return x

# %%
y_train = train_dataset.targets.numpy()

# %%
torch.manual_seed(0)

net = NeuralNetClassifier(
    ConvNet,
    lr=1e-3,
    batch_size=64,
    optimizer=optim.Adam,
    max_epochs=10,
    criterion=nn.CrossEntropyLoss,
    iterator_train__num_workers=4,
    #iterator_train__shuffle=True,
    iterator_valid__num_workers=4,
    #iterator_valid__shuffle=True,
    device=DEVICE
)

# %%
net.fit(train_dataset, y=y_train);
# Out:
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.3938       0.9687        0.1036  25.1464
#       2        0.1315       0.9786        0.0720  24.2807
#       3        0.0951       0.9799        0.0656  25.1681
#       4        0.0818       0.9856        0.0498  24.4494
#       5        0.0703       0.9882        0.0454  25.1731
#       6        0.0641       0.9867        0.0451  24.4862
#       7        0.0574       0.9894        0.0397  24.6992
#       8        0.0515       0.9877        0.0428  25.2326
#       9        0.0490       0.9888        0.0388  24.4506
#      10        0.0441       0.9897        0.0387  25.1036

# %%
net.history[:,'valid_loss']
# Out:
# [0.10364582816511393,
#  0.07200700752809644,
#  0.06556684777202705,
#  0.04978821706554542,
#  0.045449351342394945,
#  0.045120899214409295,
#  0.03966905868239701,
#  0.04283358945658741,
#  0.038756637408242874,
#  0.038652379518840464]

# %%
#net.history
# Out:
# [{'batches': [{'train_loss': 2.339961528778076, 'train_batch_size': 64},
#    {'train_loss': 2.3424384593963623, 'train_batch_size': 64},
#    {'train_loss': 2.3371973037719727, 'train_batch_size': 64},
#    {'train_loss': 2.2773642539978027, 'train_batch_size': 64},
#    {'train_loss': 2.2512619495391846, 'train_batch_size': 64},
#    {'train_loss': 2.2304959297180176, 'train_batch_size': 64},
#    {'train_loss': 2.2648723125457764, 'train_batch_size': 64},
#    {'train_loss': 2.320169687271118, 'train_batch_size': 64},
#    {'train_loss': 2.267254114151001, 'train_batch_size': 64},
#    {'train_loss': 2.379284381866455, 'train_batch_size': 64},
#    {'train_loss': 2.3210670948028564, 'train_batch_size': 64},
#    {'train_loss': 2.227051258087158, 'train_batch_size': 64},
#    {'train_loss': 2.269014596939087, 'train_batch_size': 64},
#    {'train_loss': 2.242006778717041, 'train_batch_size': 64},
#    {'train_loss': 2.2442009449005127, 'train_batch_size': 64},
#    {'train_loss': 2.2381021976470947, 'train_batch_size': 64},
#    {'train_loss': 2.2169904708862305, 'train_batch_size': 64},
#    {'train_loss': 2.1725308895111084, 'train_batch_size': 64},
#    {'train_loss': 2.1518189907073975, 'train_batch_size': 64},
#    {'train_loss': 2.13792085647583, 'train_batch_size': 64},
#    {'train_loss': 2.1460609436035156, 'train_batch_size': 64},
#    {'train_loss': 2.127434492111206, 'train_batch_size': 64},
#    {'train_loss': 2.033083200454712, 'train_batch_size': 64},
#    {'train_loss': 2.051023006439209, 'train_batch_size': 64},
#    {'train_loss': 1.9296578168869019, 'train_batch_size': 64},
#    {'train_loss': 1.9553298950195312, 'train_batch_size': 64},
#    {'train_loss': 1.94972825050354, 'train_batch_size': 64},
#    {'train_loss': 1.903206467628479, 'train_batch_size': 64},
#    {'train_loss': 1.821431040763855, 'train_batch_size': 64},
#    {'train_loss': 1.801439642906189, 'train_batch_size': 64},
#    {'train_loss': 1.8770153522491455, 'train_batch_size': 64},
#    {'train_loss': 1.7224327325820923, 'train_batch_size': 64},
#    {'train_loss': 1.6059718132019043, 'train_batch_size': 64},
#    {'train_loss': 1.5411419868469238, 'train_batch_size': 64},
#    {'train_loss': 1.5747973918914795, 'train_batch_size': 64},
#    {'train_loss': 1.6760209798812866, 'train_batch_size': 64},
#    {'train_loss': 1.4695525169372559, 'train_batch_size': 64},
#    {'train_loss': 1.4909558296203613, 'train_batch_size': 64},
#    {'train_loss': 1.4782602787017822, 'train_batch_size': 64},
#    {'train_loss': 1.4395828247070312, 'train_batch_size': 64},
#    {'train_loss': 1.214695930480957, 'train_batch_size': 64},
#    {'train_loss': 1.6409493684768677, 'train_batch_size': 64},
#    {'train_loss': 1.6516345739364624, 'train_batch_size': 64},
#    {'train_loss': 1.409213662147522, 'train_batch_size': 64},
#    {'train_loss': 1.3717612028121948, 'train_batch_size': 64},
#    {'train_loss': 1.2060807943344116, 'train_batch_size': 64},
#    {'train_loss': 1.0690232515335083, 'train_batch_size': 64},
#    {'train_loss': 1.113146424293518, 'train_batch_size': 64},
#    {'train_loss': 1.1195868253707886, 'train_batch_size': 64},
#    {'train_loss': 1.0404961109161377, 'train_batch_size': 64},
#    {'train_loss': 1.0057674646377563, 'train_batch_size': 64},
#    {'train_loss': 0.992150604724884, 'train_batch_size': 64},
#    {'train_loss': 1.119461178779602, 'train_batch_size': 64},
#    {'train_loss': 0.9840441346168518, 'train_batch_size': 64},
#    {'train_loss': 0.9082024097442627, 'train_batch_size': 64},
#    {'train_loss': 0.7400853633880615, 'train_batch_size': 64},
#    {'train_loss': 0.8884847164154053, 'train_batch_size': 64},
#    {'train_loss': 0.769182562828064, 'train_batch_size': 64},
#    {'train_loss': 1.2176114320755005, 'train_batch_size': 64},
#    {'train_loss': 0.848510205745697, 'train_batch_size': 64},
#    {'train_loss': 1.0928562879562378, 'train_batch_size': 64},
#    {'train_loss': 1.0579942464828491, 'train_batch_size': 64},
#    {'train_loss': 1.080322504043579, 'train_batch_size': 64},
#    {'train_loss': 1.4389441013336182, 'train_batch_size': 64},
#    {'train_loss': 0.7646458745002747, 'train_batch_size': 64},
#    {'train_loss': 1.0755996704101562, 'train_batch_size': 64},
#    {'train_loss': 0.6552488207817078, 'train_batch_size': 64},
#    {'train_loss': 0.5937078595161438, 'train_batch_size': 64},
#    {'train_loss': 0.7099238038063049, 'train_batch_size': 64},
#    {'train_loss': 0.6902013421058655, 'train_batch_size': 64},
#    {'train_loss': 0.6136534214019775, 'train_batch_size': 64},
#    {'train_loss': 0.7983570098876953, 'train_batch_size': 64},
#    {'train_loss': 0.711644172668457, 'train_batch_size': 64},
#    {'train_loss': 0.7824000120162964, 'train_batch_size': 64},
#    {'train_loss': 0.9646640419960022, 'train_batch_size': 64},
#    {'train_loss': 0.7860870957374573, 'train_batch_size': 64},
#    {'train_loss': 0.6503930687904358, 'train_batch_size': 64},
#    {'train_loss': 0.9168590903282166, 'train_batch_size': 64},
#    {'train_loss': 0.7521135210990906, 'train_batch_size': 64},
#    {'train_loss': 0.8510922193527222, 'train_batch_size': 64},
#    {'train_loss': 0.6077552437782288, 'train_batch_size': 64},
#    {'train_loss': 0.9033671617507935, 'train_batch_size': 64},
#    {'train_loss': 0.697864830493927, 'train_batch_size': 64},
#    {'train_loss': 0.5508596897125244, 'train_batch_size': 64},
#    {'train_loss': 0.7881056070327759, 'train_batch_size': 64},
#    {'train_loss': 0.7135607004165649, 'train_batch_size': 64},
#    {'train_loss': 0.8092432618141174, 'train_batch_size': 64},
#    {'train_loss': 0.6872877478599548, 'train_batch_size': 64},
#    {'train_loss': 0.64351487159729, 'train_batch_size': 64},
#    {'train_loss': 0.7783514261245728, 'train_batch_size': 64},
#    {'train_loss': 0.7688977122306824, 'train_batch_size': 64},
#    {'train_loss': 0.6050031185150146, 'train_batch_size': 64},
#    {'train_loss': 0.6292607188224792, 'train_batch_size': 64},
#    {'train_loss': 0.5869380831718445, 'train_batch_size': 64},
#    {'train_loss': 0.5672875046730042, 'train_batch_size': 64},
#    {'train_loss': 0.5900098085403442, 'train_batch_size': 64},
#    {'train_loss': 0.3974227011203766, 'train_batch_size': 64},
#    {'train_loss': 0.4975515305995941, 'train_batch_size': 64},
#    {'train_loss': 0.4782370328903198, 'train_batch_size': 64},
#    {'train_loss': 0.6003301739692688, 'train_batch_size': 64},
#    {'train_loss': 0.7651565074920654, 'train_batch_size': 64},
#    {'train_loss': 0.6586859226226807, 'train_batch_size': 64},
#    {'train_loss': 0.42274022102355957, 'train_batch_size': 64},
#    {'train_loss': 0.5133494138717651, 'train_batch_size': 64},
#    {'train_loss': 0.4103452265262604, 'train_batch_size': 64},
#    {'train_loss': 0.4458668828010559, 'train_batch_size': 64},
#    {'train_loss': 0.5569180250167847, 'train_batch_size': 64},
#    {'train_loss': 0.30670538544654846, 'train_batch_size': 64},
#    {'train_loss': 0.2544621527194977, 'train_batch_size': 64},
#    {'train_loss': 0.53411465883255, 'train_batch_size': 64},
#    {'train_loss': 0.6801634430885315, 'train_batch_size': 64},
#    {'train_loss': 0.5456796288490295, 'train_batch_size': 64},
#    {'train_loss': 0.6993857026100159, 'train_batch_size': 64},
#    {'train_loss': 0.4610878825187683, 'train_batch_size': 64},
#    {'train_loss': 0.4019812345504761, 'train_batch_size': 64},
#    {'train_loss': 0.3993559777736664, 'train_batch_size': 64},
#    {'train_loss': 0.4871176779270172, 'train_batch_size': 64},
#    {'train_loss': 0.49664899706840515, 'train_batch_size': 64},
#    {'train_loss': 0.45131534337997437, 'train_batch_size': 64},
#    {'train_loss': 0.2788126468658447, 'train_batch_size': 64},
#    {'train_loss': 0.23415803909301758, 'train_batch_size': 64},
#    {'train_loss': 0.3232738673686981, 'train_batch_size': 64},
#    {'train_loss': 0.45428717136383057, 'train_batch_size': 64},
#    {'train_loss': 0.42608922719955444, 'train_batch_size': 64},
#    {'train_loss': 0.4569452702999115, 'train_batch_size': 64},
#    {'train_loss': 0.7133395671844482, 'train_batch_size': 64},
#    {'train_loss': 0.638329267501831, 'train_batch_size': 64},
#    {'train_loss': 0.6541710495948792, 'train_batch_size': 64},
#    {'train_loss': 0.503255307674408, 'train_batch_size': 64},
#    {'train_loss': 0.3075113892555237, 'train_batch_size': 64},
#    {'train_loss': 0.37519821524620056, 'train_batch_size': 64},
#    {'train_loss': 0.3355807960033417, 'train_batch_size': 64},
#    {'train_loss': 0.297187864780426, 'train_batch_size': 64},
#    {'train_loss': 0.5243590474128723, 'train_batch_size': 64},
#    {'train_loss': 0.36096274852752686, 'train_batch_size': 64},
#    {'train_loss': 0.45785295963287354, 'train_batch_size': 64},
#    {'train_loss': 0.6069387197494507, 'train_batch_size': 64},
#    {'train_loss': 0.6367117166519165, 'train_batch_size': 64},
#    {'train_loss': 0.5477089285850525, 'train_batch_size': 64},
#    {'train_loss': 0.5779274702072144, 'train_batch_size': 64},
#    {'train_loss': 0.43254923820495605, 'train_batch_size': 64},
#    {'train_loss': 0.3642316460609436, 'train_batch_size': 64},
#    {'train_loss': 0.3491121232509613, 'train_batch_size': 64},
#    {'train_loss': 0.38793155550956726, 'train_batch_size': 64},
#    {'train_loss': 0.21941497921943665, 'train_batch_size': 64},
#    {'train_loss': 0.4496520757675171, 'train_batch_size': 64},
#    {'train_loss': 0.5750643610954285, 'train_batch_size': 64},
#    {'train_loss': 0.49628496170043945, 'train_batch_size': 64},
#    {'train_loss': 0.23922447860240936, 'train_batch_size': 64},
#    {'train_loss': 0.5443651080131531, 'train_batch_size': 64},
#    {'train_loss': 0.3070635497570038, 'train_batch_size': 64},
#    {'train_loss': 0.3474547564983368, 'train_batch_size': 64},
#    {'train_loss': 0.1435912698507309, 'train_batch_size': 64},
#    {'train_loss': 0.2408107966184616, 'train_batch_size': 64},
#    {'train_loss': 0.2799157500267029, 'train_batch_size': 64},
#    {'train_loss': 0.3432065546512604, 'train_batch_size': 64},
#    {'train_loss': 0.26207810640335083, 'train_batch_size': 64},
#    {'train_loss': 0.3998521864414215, 'train_batch_size': 64},
#    {'train_loss': 0.5237007737159729, 'train_batch_size': 64},
#    {'train_loss': 0.6379665732383728, 'train_batch_size': 64},
#    {'train_loss': 0.39308613538742065, 'train_batch_size': 64},
#    {'train_loss': 0.33076179027557373, 'train_batch_size': 64},
#    {'train_loss': 0.2848713994026184, 'train_batch_size': 64},
#    {'train_loss': 0.5905128717422485, 'train_batch_size': 64},
#    {'train_loss': 0.5087980031967163, 'train_batch_size': 64},
#    {'train_loss': 0.5691741704940796, 'train_batch_size': 64},
#    {'train_loss': 0.5946615934371948, 'train_batch_size': 64},
#    {'train_loss': 0.3578449785709381, 'train_batch_size': 64},
#    {'train_loss': 0.46470800042152405, 'train_batch_size': 64},
#    {'train_loss': 0.4082465171813965, 'train_batch_size': 64},
#    {'train_loss': 0.2796204388141632, 'train_batch_size': 64},
#    {'train_loss': 0.2083117812871933, 'train_batch_size': 64},
#    {'train_loss': 0.40393614768981934, 'train_batch_size': 64},
#    {'train_loss': 0.4200746715068817, 'train_batch_size': 64},
#    {'train_loss': 0.42942506074905396, 'train_batch_size': 64},
#    {'train_loss': 0.2194978892803192, 'train_batch_size': 64},
#    {'train_loss': 0.2397572249174118, 'train_batch_size': 64},
#    {'train_loss': 0.3457984924316406, 'train_batch_size': 64},
#    {'train_loss': 0.26338282227516174, 'train_batch_size': 64},
#    {'train_loss': 0.29707562923431396, 'train_batch_size': 64},
#    {'train_loss': 0.3703550398349762, 'train_batch_size': 64},
#    {'train_loss': 0.45991262793540955, 'train_batch_size': 64},
#    {'train_loss': 0.3746468126773834, 'train_batch_size': 64},
#    {'train_loss': 0.3971349596977234, 'train_batch_size': 64},
#    {'train_loss': 0.5025174021720886, 'train_batch_size': 64},
#    {'train_loss': 0.3241998255252838, 'train_batch_size': 64},
#    {'train_loss': 0.44874900579452515, 'train_batch_size': 64},
#    {'train_loss': 0.22818128764629364, 'train_batch_size': 64},
#    {'train_loss': 0.4207441806793213, 'train_batch_size': 64},
#    {'train_loss': 0.27762627601623535, 'train_batch_size': 64},
#    {'train_loss': 0.42961034178733826, 'train_batch_size': 64},
#    {'train_loss': 0.6495400071144104, 'train_batch_size': 64},
#    {'train_loss': 0.26037564873695374, 'train_batch_size': 64},
#    {'train_loss': 0.24031728506088257, 'train_batch_size': 64},
#    {'train_loss': 0.30773264169692993, 'train_batch_size': 64},
#    {'train_loss': 0.5126944780349731, 'train_batch_size': 64},
#    {'train_loss': 0.3654521703720093, 'train_batch_size': 64},
#    {'train_loss': 0.5544187426567078, 'train_batch_size': 64},
#    {'train_loss': 0.4126429259777069, 'train_batch_size': 64},
#    {'train_loss': 0.4885735511779785, 'train_batch_size': 64},
#    {'train_loss': 0.3313734531402588, 'train_batch_size': 64},
#    {'train_loss': 0.2891131043434143, 'train_batch_size': 64},
#    {'train_loss': 0.46075937151908875, 'train_batch_size': 64},
#    {'train_loss': 0.18934045732021332, 'train_batch_size': 64},
#    {'train_loss': 0.30151689052581787, 'train_batch_size': 64},
#    {'train_loss': 0.36660975217819214, 'train_batch_size': 64},
#    {'train_loss': 0.3362349271774292, 'train_batch_size': 64},
#    {'train_loss': 0.35632988810539246, 'train_batch_size': 64},
#    {'train_loss': 0.18213503062725067, 'train_batch_size': 64},
#    {'train_loss': 0.20661316812038422, 'train_batch_size': 64},
#    {'train_loss': 0.2806853652000427, 'train_batch_size': 64},
#    {'train_loss': 0.21057051420211792, 'train_batch_size': 64},
#    {'train_loss': 0.32860276103019714, 'train_batch_size': 64},
#    {'train_loss': 0.20790798962116241, 'train_batch_size': 64},
#    {'train_loss': 0.2844066023826599, 'train_batch_size': 64},
#    {'train_loss': 0.46866318583488464, 'train_batch_size': 64},
#    {'train_loss': 0.29836514592170715, 'train_batch_size': 64},
#    {'train_loss': 0.2726173996925354, 'train_batch_size': 64},
#    {'train_loss': 0.1918841451406479, 'train_batch_size': 64},
#    {'train_loss': 0.27565836906433105, 'train_batch_size': 64},
#    {'train_loss': 0.25339627265930176, 'train_batch_size': 64},
#    {'train_loss': 0.16880835592746735, 'train_batch_size': 64},
#    {'train_loss': 0.24842305481433868, 'train_batch_size': 64},
#    {'train_loss': 0.19349196553230286, 'train_batch_size': 64},
#    {'train_loss': 0.5914483070373535, 'train_batch_size': 64},
#    {'train_loss': 0.32727494835853577, 'train_batch_size': 64},
#    {'train_loss': 0.3056172728538513, 'train_batch_size': 64},
#    {'train_loss': 0.27603915333747864, 'train_batch_size': 64},
#    {'train_loss': 0.5420093536376953, 'train_batch_size': 64},
#    {'train_loss': 0.2419215589761734, 'train_batch_size': 64},
#    {'train_loss': 0.6117867827415466, 'train_batch_size': 64},
#    {'train_loss': 0.16996678709983826, 'train_batch_size': 64},
#    {'train_loss': 0.5334278345108032, 'train_batch_size': 64},
#    {'train_loss': 0.20367367565631866, 'train_batch_size': 64},
#    {'train_loss': 0.17178680002689362, 'train_batch_size': 64},
#    {'train_loss': 0.2749866545200348, 'train_batch_size': 64},
#    {'train_loss': 0.5209375023841858, 'train_batch_size': 64},
#    {'train_loss': 0.5566717982292175, 'train_batch_size': 64},
#    {'train_loss': 0.30787843465805054, 'train_batch_size': 64},
#    {'train_loss': 0.2905890941619873, 'train_batch_size': 64},
#    {'train_loss': 0.23716488480567932, 'train_batch_size': 64},
#    {'train_loss': 0.35259804129600525, 'train_batch_size': 64},
#    {'train_loss': 0.2901737093925476, 'train_batch_size': 64},
#    {'train_loss': 0.25645217299461365, 'train_batch_size': 64},
#    {'train_loss': 0.3726835548877716, 'train_batch_size': 64},
#    {'train_loss': 0.3684394657611847, 'train_batch_size': 64},
#    {'train_loss': 0.27557793259620667, 'train_batch_size': 64},
#    {'train_loss': 0.28570833802223206, 'train_batch_size': 64},
#    {'train_loss': 0.2655597925186157, 'train_batch_size': 64},
#    {'train_loss': 0.25708454847335815, 'train_batch_size': 64},
#    {'train_loss': 0.14194707572460175, 'train_batch_size': 64},
#    {'train_loss': 0.12591224908828735, 'train_batch_size': 64},
#    {'train_loss': 0.31080958247184753, 'train_batch_size': 64},
#    {'train_loss': 0.2936151921749115, 'train_batch_size': 64},
#    {'train_loss': 0.26839929819107056, 'train_batch_size': 64},
#    {'train_loss': 0.3400931656360626, 'train_batch_size': 64},
#    {'train_loss': 0.29503029584884644, 'train_batch_size': 64},
#    {'train_loss': 0.16839687526226044, 'train_batch_size': 64},
#    {'train_loss': 0.3921341300010681, 'train_batch_size': 64},
#    {'train_loss': 0.3878611624240875, 'train_batch_size': 64},
#    {'train_loss': 0.5965467691421509, 'train_batch_size': 64},
#    {'train_loss': 0.35218897461891174, 'train_batch_size': 64},
#    {'train_loss': 0.41044944524765015, 'train_batch_size': 64},
#    {'train_loss': 0.2585084140300751, 'train_batch_size': 64},
#    {'train_loss': 0.36437222361564636, 'train_batch_size': 64},
#    {'train_loss': 0.2547791600227356, 'train_batch_size': 64},
#    {'train_loss': 0.3330078125, 'train_batch_size': 64},
#    {'train_loss': 0.2938076853752136, 'train_batch_size': 64},
#    {'train_loss': 0.37586623430252075, 'train_batch_size': 64},
#    {'train_loss': 0.27560368180274963, 'train_batch_size': 64},
#    {'train_loss': 0.3853626251220703, 'train_batch_size': 64},
#    {'train_loss': 0.19719800353050232, 'train_batch_size': 64},
#    {'train_loss': 0.4038889706134796, 'train_batch_size': 64},
#    {'train_loss': 0.3555986285209656, 'train_batch_size': 64},
#    {'train_loss': 0.3890877366065979, 'train_batch_size': 64},
#    {'train_loss': 0.13820138573646545, 'train_batch_size': 64},
#    {'train_loss': 0.3617613911628723, 'train_batch_size': 64},
#    {'train_loss': 0.32315173745155334, 'train_batch_size': 64},
#    {'train_loss': 0.3225313425064087, 'train_batch_size': 64},
#    {'train_loss': 0.28908300399780273, 'train_batch_size': 64},
#    {'train_loss': 0.37944406270980835, 'train_batch_size': 64},
#    {'train_loss': 0.2390977442264557, 'train_batch_size': 64},
#    {'train_loss': 0.3619054853916168, 'train_batch_size': 64},
#    {'train_loss': 0.47289538383483887, 'train_batch_size': 64},
#    {'train_loss': 0.2365153282880783, 'train_batch_size': 64},
#    {'train_loss': 0.21076545119285583, 'train_batch_size': 64},
#    {'train_loss': 0.19545480608940125, 'train_batch_size': 64},
#    {'train_loss': 0.37391403317451477, 'train_batch_size': 64},
#    {'train_loss': 0.32541465759277344, 'train_batch_size': 64},
#    {'train_loss': 0.3442027270793915, 'train_batch_size': 64},
#    {'train_loss': 0.3626369833946228, 'train_batch_size': 64},
#    {'train_loss': 0.2589232623577118, 'train_batch_size': 64},
#    {'train_loss': 0.3467964828014374, 'train_batch_size': 64},
#    {'train_loss': 0.21099427342414856, 'train_batch_size': 64},
#    {'train_loss': 0.40125080943107605, 'train_batch_size': 64},
#    {'train_loss': 0.39800798892974854, 'train_batch_size': 64},
#    {'train_loss': 0.24293309450149536, 'train_batch_size': 64},
#    {'train_loss': 0.21490833163261414, 'train_batch_size': 64},
#    {'train_loss': 0.5201401710510254, 'train_batch_size': 64},
#    {'train_loss': 0.48712554574012756, 'train_batch_size': 64},
#    {'train_loss': 0.3236525058746338, 'train_batch_size': 64},
#    {'train_loss': 0.540733814239502, 'train_batch_size': 64},
#    {'train_loss': 0.2319229543209076, 'train_batch_size': 64},
#    {'train_loss': 0.3717654049396515, 'train_batch_size': 64},
#    {'train_loss': 0.2524019181728363, 'train_batch_size': 64},
#    {'train_loss': 0.15498602390289307, 'train_batch_size': 64},
#    {'train_loss': 0.4269567131996155, 'train_batch_size': 64},
#    {'train_loss': 0.41977551579475403, 'train_batch_size': 64},
#    {'train_loss': 0.3060804605484009, 'train_batch_size': 64},
#    {'train_loss': 0.204659104347229, 'train_batch_size': 64},
#    {'train_loss': 0.3887913227081299, 'train_batch_size': 64},
#    {'train_loss': 0.2636927366256714, 'train_batch_size': 64},
#    {'train_loss': 0.19803251326084137, 'train_batch_size': 64},
#    {'train_loss': 0.32074061036109924, 'train_batch_size': 64},
#    {'train_loss': 0.28398579359054565, 'train_batch_size': 64},
#    {'train_loss': 0.24852466583251953, 'train_batch_size': 64},
#    {'train_loss': 0.2799037992954254, 'train_batch_size': 64},
#    {'train_loss': 0.5046394467353821, 'train_batch_size': 64},
#    {'train_loss': 0.4194585978984833, 'train_batch_size': 64},
#    {'train_loss': 0.2139407843351364, 'train_batch_size': 64},
#    {'train_loss': 0.3597538471221924, 'train_batch_size': 64},
#    {'train_loss': 0.15726952254772186, 'train_batch_size': 64},
#    {'train_loss': 0.1314975470304489, 'train_batch_size': 64},
#    {'train_loss': 0.2028352916240692, 'train_batch_size': 64},
#    {'train_loss': 0.42920660972595215, 'train_batch_size': 64},
#    {'train_loss': 0.19298100471496582, 'train_batch_size': 64},
#    {'train_loss': 0.232780322432518, 'train_batch_size': 64},
#    {'train_loss': 0.07935010641813278, 'train_batch_size': 64},
#    {'train_loss': 0.2006489634513855, 'train_batch_size': 64},
#    {'train_loss': 0.15335306525230408, 'train_batch_size': 64},
#    {'train_loss': 0.19331815838813782, 'train_batch_size': 64},
#    {'train_loss': 0.2670603394508362, 'train_batch_size': 64},
#    {'train_loss': 0.09733806550502777, 'train_batch_size': 64},
#    {'train_loss': 0.33409133553504944, 'train_batch_size': 64},
#    {'train_loss': 0.3964211940765381, 'train_batch_size': 64},
#    {'train_loss': 0.15446174144744873, 'train_batch_size': 64},
#    {'train_loss': 0.22030840814113617, 'train_batch_size': 64},
#    {'train_loss': 0.24184274673461914, 'train_batch_size': 64},
#    {'train_loss': 0.13832534849643707, 'train_batch_size': 64},
#    {'train_loss': 0.235904261469841, 'train_batch_size': 64},
#    {'train_loss': 0.24061842262744904, 'train_batch_size': 64},
#    {'train_loss': 0.10760544240474701, 'train_batch_size': 64},
#    {'train_loss': 0.08561138808727264, 'train_batch_size': 64},
#    {'train_loss': 0.17914310097694397, 'train_batch_size': 64},
#    {'train_loss': 0.22491873800754547, 'train_batch_size': 64},
#    {'train_loss': 0.17849837243556976, 'train_batch_size': 64},
#    {'train_loss': 0.10485535860061646, 'train_batch_size': 64},
#    {'train_loss': 0.17534679174423218, 'train_batch_size': 64},
#    {'train_loss': 0.2053491473197937, 'train_batch_size': 64},
#    {'train_loss': 0.1784883588552475, 'train_batch_size': 64},
#    {'train_loss': 0.38908857107162476, 'train_batch_size': 64},
#    {'train_loss': 0.15074336528778076, 'train_batch_size': 64},
#    {'train_loss': 0.2694174349308014, 'train_batch_size': 64},
#    {'train_loss': 0.11129824817180634, 'train_batch_size': 64},
#    {'train_loss': 0.5844714641571045, 'train_batch_size': 64},
#    {'train_loss': 0.23666605353355408, 'train_batch_size': 64},
#    {'train_loss': 0.365090012550354, 'train_batch_size': 64},
#    {'train_loss': 0.3686951696872711, 'train_batch_size': 64},
#    {'train_loss': 0.17726464569568634, 'train_batch_size': 64},
#    {'train_loss': 0.21271054446697235, 'train_batch_size': 64},
#    {'train_loss': 0.16788923740386963, 'train_batch_size': 64},
#    {'train_loss': 0.20558959245681763, 'train_batch_size': 64},
#    {'train_loss': 0.14730076491832733, 'train_batch_size': 64},
#    {'train_loss': 0.3797306716442108, 'train_batch_size': 64},
#    {'train_loss': 0.12417472153902054, 'train_batch_size': 64},
#    {'train_loss': 0.27902039885520935, 'train_batch_size': 64},
#    {'train_loss': 0.30491873621940613, 'train_batch_size': 64},
#    {'train_loss': 0.1329667717218399, 'train_batch_size': 64},
#    {'train_loss': 0.1507309377193451, 'train_batch_size': 64},
#    {'train_loss': 0.2691035568714142, 'train_batch_size': 64},
#    {'train_loss': 0.2778400480747223, 'train_batch_size': 64},
#    {'train_loss': 0.09000665694475174, 'train_batch_size': 64},
#    {'train_loss': 0.23718175292015076, 'train_batch_size': 64},
#    {'train_loss': 0.2624974250793457, 'train_batch_size': 64},
#    {'train_loss': 0.25550925731658936, 'train_batch_size': 64},
#    {'train_loss': 0.3557162582874298, 'train_batch_size': 64},
#    {'train_loss': 0.31837430596351624, 'train_batch_size': 64},
#    {'train_loss': 0.18111610412597656, 'train_batch_size': 64},
#    {'train_loss': 0.14985297620296478, 'train_batch_size': 64},
#    {'train_loss': 0.07323825359344482, 'train_batch_size': 64},
#    {'train_loss': 0.15511295199394226, 'train_batch_size': 64},
#    {'train_loss': 0.37368953227996826, 'train_batch_size': 64},
#    {'train_loss': 0.19616390764713287, 'train_batch_size': 64},
#    {'train_loss': 0.1329721063375473, 'train_batch_size': 64},
#    {'train_loss': 0.1762191653251648, 'train_batch_size': 64},
#    {'train_loss': 0.2142110913991928, 'train_batch_size': 64},
#    {'train_loss': 0.39732858538627625, 'train_batch_size': 64},
#    {'train_loss': 0.25516706705093384, 'train_batch_size': 64},
#    {'train_loss': 0.347795307636261, 'train_batch_size': 64},
#    {'train_loss': 0.20713961124420166, 'train_batch_size': 64},
#    {'train_loss': 0.1168002262711525, 'train_batch_size': 64},
#    {'train_loss': 0.23591212928295135, 'train_batch_size': 64},
#    {'train_loss': 0.26512908935546875, 'train_batch_size': 64},
#    {'train_loss': 0.21925316751003265, 'train_batch_size': 64},
#    {'train_loss': 0.18568292260169983, 'train_batch_size': 64},
#    {'train_loss': 0.3037976324558258, 'train_batch_size': 64},
#    {'train_loss': 0.5730012655258179, 'train_batch_size': 64},
#    {'train_loss': 0.39986950159072876, 'train_batch_size': 64},
#    {'train_loss': 0.1352863907814026, 'train_batch_size': 64},
#    {'train_loss': 0.24985606968402863, 'train_batch_size': 64},
#    {'train_loss': 0.135981485247612, 'train_batch_size': 64},
#    {'train_loss': 0.22888854146003723, 'train_batch_size': 64},
#    {'train_loss': 0.1941356062889099, 'train_batch_size': 64},
#    {'train_loss': 0.16091591119766235, 'train_batch_size': 64},
#    {'train_loss': 0.31076982617378235, 'train_batch_size': 64},
#    {'train_loss': 0.20476596057415009, 'train_batch_size': 64},
#    {'train_loss': 0.1846258044242859, 'train_batch_size': 64},
#    {'train_loss': 0.16709867119789124, 'train_batch_size': 64},
#    {'train_loss': 0.128080353140831, 'train_batch_size': 64},
#    {'train_loss': 0.1952553540468216, 'train_batch_size': 64},
#    {'train_loss': 0.16651815176010132, 'train_batch_size': 64},
#    {'train_loss': 0.23427337408065796, 'train_batch_size': 64},
#    {'train_loss': 0.31009677052497864, 'train_batch_size': 64},
#    {'train_loss': 0.14371880888938904, 'train_batch_size': 64},
#    {'train_loss': 0.2709205150604248, 'train_batch_size': 64},
#    {'train_loss': 0.3940563201904297, 'train_batch_size': 64},
#    {'train_loss': 0.21127822995185852, 'train_batch_size': 64},
#    {'train_loss': 0.2330857664346695, 'train_batch_size': 64},
#    {'train_loss': 0.33895736932754517, 'train_batch_size': 64},
#    {'train_loss': 0.10148108750581741, 'train_batch_size': 64},
#    {'train_loss': 0.15439921617507935, 'train_batch_size': 64},
#    {'train_loss': 0.23547214269638062, 'train_batch_size': 64},
#    {'train_loss': 0.10123338550329208, 'train_batch_size': 64},
#    {'train_loss': 0.2526934742927551, 'train_batch_size': 64},
#    {'train_loss': 0.11603997647762299, 'train_batch_size': 64},
#    {'train_loss': 0.27099767327308655, 'train_batch_size': 64},
#    {'train_loss': 0.4633978009223938, 'train_batch_size': 64},
#    {'train_loss': 0.260699599981308, 'train_batch_size': 64},
#    {'train_loss': 0.2511681616306305, 'train_batch_size': 64},
#    {'train_loss': 0.21696940064430237, 'train_batch_size': 64},
#    {'train_loss': 0.07084613293409348, 'train_batch_size': 64},
#    {'train_loss': 0.2635226547718048, 'train_batch_size': 64},
#    {'train_loss': 0.3183175325393677, 'train_batch_size': 64},
#    {'train_loss': 0.24178610742092133, 'train_batch_size': 64},
#    {'train_loss': 0.2827133536338806, 'train_batch_size': 64},
#    {'train_loss': 0.34108680486679077, 'train_batch_size': 64},
#    {'train_loss': 0.2269132137298584, 'train_batch_size': 64},
#    {'train_loss': 0.20158809423446655, 'train_batch_size': 64},
#    {'train_loss': 0.11231689155101776, 'train_batch_size': 64},
#    {'train_loss': 0.14888492226600647, 'train_batch_size': 64},
#    {'train_loss': 0.10490287095308304, 'train_batch_size': 64},
#    {'train_loss': 0.20678360760211945, 'train_batch_size': 64},
#    {'train_loss': 0.12560471892356873, 'train_batch_size': 64},
#    {'train_loss': 0.2163466215133667, 'train_batch_size': 64},
#    {'train_loss': 0.13853034377098083, 'train_batch_size': 64},
#    {'train_loss': 0.1559179425239563, 'train_batch_size': 64},
#    {'train_loss': 0.148489847779274, 'train_batch_size': 64},
#    {'train_loss': 0.27677202224731445, 'train_batch_size': 64},
#    {'train_loss': 0.16316674649715424, 'train_batch_size': 64},
#    {'train_loss': 0.17298509180545807, 'train_batch_size': 64},
#    {'train_loss': 0.21533337235450745, 'train_batch_size': 64},
#    {'train_loss': 0.10316134989261627, 'train_batch_size': 64},
#    {'train_loss': 0.2310837060213089, 'train_batch_size': 64},
#    {'train_loss': 0.13078553974628448, 'train_batch_size': 64},
#    {'train_loss': 0.2539340555667877, 'train_batch_size': 64},
#    {'train_loss': 0.06411875784397125, 'train_batch_size': 64},
#    {'train_loss': 0.11249954998493195, 'train_batch_size': 64},
#    {'train_loss': 0.5041030645370483, 'train_batch_size': 64},
#    {'train_loss': 0.21611034870147705, 'train_batch_size': 64},
#    {'train_loss': 0.48329997062683105, 'train_batch_size': 64},
#    {'train_loss': 0.21080279350280762, 'train_batch_size': 64},
#    {'train_loss': 0.19494053721427917, 'train_batch_size': 64},
#    {'train_loss': 0.21739844977855682, 'train_batch_size': 64},
#    {'train_loss': 0.12727299332618713, 'train_batch_size': 64},
#    {'train_loss': 0.2871182858943939, 'train_batch_size': 64},
#    {'train_loss': 0.1352071315050125, 'train_batch_size': 64},
#    {'train_loss': 0.1945631206035614, 'train_batch_size': 64},
#    {'train_loss': 0.20049525797367096, 'train_batch_size': 64},
#    {'train_loss': 0.3033175468444824, 'train_batch_size': 64},
#    {'train_loss': 0.13173571228981018, 'train_batch_size': 64},
#    {'train_loss': 0.2640446424484253, 'train_batch_size': 64},
#    {'train_loss': 0.3386271595954895, 'train_batch_size': 64},
#    {'train_loss': 0.17413771152496338, 'train_batch_size': 64},
#    {'train_loss': 0.23595714569091797, 'train_batch_size': 64},
#    {'train_loss': 0.22754275798797607, 'train_batch_size': 64},
#    {'train_loss': 0.3906751275062561, 'train_batch_size': 64},
#    {'train_loss': 0.55010986328125, 'train_batch_size': 64},
#    {'train_loss': 0.31740695238113403, 'train_batch_size': 64},
#    {'train_loss': 0.1169828325510025, 'train_batch_size': 64},
#    {'train_loss': 0.18213680386543274, 'train_batch_size': 64},
#    {'train_loss': 0.15780045092105865, 'train_batch_size': 64},
#    {'train_loss': 0.18473181128501892, 'train_batch_size': 64},
#    {'train_loss': 0.32337936758995056, 'train_batch_size': 64},
#    {'train_loss': 0.4418381452560425, 'train_batch_size': 64},
#    {'train_loss': 0.31433814764022827, 'train_batch_size': 64},
#    {'train_loss': 0.3250562250614166, 'train_batch_size': 64},
#    {'train_loss': 0.18978473544120789, 'train_batch_size': 64},
#    {'train_loss': 0.22419211268424988, 'train_batch_size': 64},
#    {'train_loss': 0.1315511167049408, 'train_batch_size': 64},
#    {'train_loss': 0.12096492201089859, 'train_batch_size': 64},
#    {'train_loss': 0.10481744259595871, 'train_batch_size': 64},
#    {'train_loss': 0.15953469276428223, 'train_batch_size': 64},
#    {'train_loss': 0.14298783242702484, 'train_batch_size': 64},
#    {'train_loss': 0.15045447647571564, 'train_batch_size': 64},
#    {'train_loss': 0.3441770374774933, 'train_batch_size': 64},
#    {'train_loss': 0.11026531457901001, 'train_batch_size': 64},
#    {'train_loss': 0.22287897765636444, 'train_batch_size': 64},
#    {'train_loss': 0.12738297879695892, 'train_batch_size': 64},
#    {'train_loss': 0.18524736166000366, 'train_batch_size': 64},
#    {'train_loss': 0.292350709438324, 'train_batch_size': 64},
#    {'train_loss': 0.07923868298530579, 'train_batch_size': 64},
#    {'train_loss': 0.2299213409423828, 'train_batch_size': 64},
#    {'train_loss': 0.2372303009033203, 'train_batch_size': 64},
#    {'train_loss': 0.1530143767595291, 'train_batch_size': 64},
#    {'train_loss': 0.19388717412948608, 'train_batch_size': 64},
#    {'train_loss': 0.290395051240921, 'train_batch_size': 64},
#    {'train_loss': 0.2967492341995239, 'train_batch_size': 64},
#    {'train_loss': 0.2654876112937927, 'train_batch_size': 64},
#    {'train_loss': 0.10249108821153641, 'train_batch_size': 64},
#    {'train_loss': 0.17669090628623962, 'train_batch_size': 64},
#    {'train_loss': 0.04993443936109543, 'train_batch_size': 64},
#    {'train_loss': 0.22481416165828705, 'train_batch_size': 64},
#    {'train_loss': 0.07851745933294296, 'train_batch_size': 64},
#    {'train_loss': 0.35903117060661316, 'train_batch_size': 64},
#    {'train_loss': 0.1248362809419632, 'train_batch_size': 64},
#    {'train_loss': 0.1590086668729782, 'train_batch_size': 64},
#    {'train_loss': 0.22631128132343292, 'train_batch_size': 64},
#    {'train_loss': 0.4058299660682678, 'train_batch_size': 64},
#    {'train_loss': 0.1630457639694214, 'train_batch_size': 64},
#    {'train_loss': 0.05575811117887497, 'train_batch_size': 64},
#    {'train_loss': 0.04121019318699837, 'train_batch_size': 64},
#    {'train_loss': 0.1486879587173462, 'train_batch_size': 64},
#    {'train_loss': 0.27359315752983093, 'train_batch_size': 64},
#    {'train_loss': 0.2372911423444748, 'train_batch_size': 64},
#    {'train_loss': 0.3011258542537689, 'train_batch_size': 64},
#    {'train_loss': 0.22245261073112488, 'train_batch_size': 64},
#    {'train_loss': 0.08895394951105118, 'train_batch_size': 64},
#    {'train_loss': 0.3663478195667267, 'train_batch_size': 64},
#    {'train_loss': 0.33697354793548584, 'train_batch_size': 64},
#    {'train_loss': 0.353394091129303, 'train_batch_size': 64},
#    {'train_loss': 0.1734749674797058, 'train_batch_size': 64},
#    {'train_loss': 0.14254185557365417, 'train_batch_size': 64},
#    {'train_loss': 0.3227335810661316, 'train_batch_size': 64},
#    {'train_loss': 0.2727527320384979, 'train_batch_size': 64},
#    {'train_loss': 0.20607894659042358, 'train_batch_size': 64},
#    {'train_loss': 0.3722284734249115, 'train_batch_size': 64},
#    {'train_loss': 0.2535742223262787, 'train_batch_size': 64},
#    {'train_loss': 0.2528705298900604, 'train_batch_size': 64},
#    {'train_loss': 0.20520828664302826, 'train_batch_size': 64},
#    {'train_loss': 0.0936082974076271, 'train_batch_size': 64},
#    {'train_loss': 0.22279013693332672, 'train_batch_size': 64},
#    {'train_loss': 0.07462361454963684, 'train_batch_size': 64},
#    {'train_loss': 0.3199407756328583, 'train_batch_size': 64},
#    {'train_loss': 0.18120597302913666, 'train_batch_size': 64},
#    {'train_loss': 0.13393354415893555, 'train_batch_size': 64},
#    {'train_loss': 0.16579489409923553, 'train_batch_size': 64},
#    {'train_loss': 0.11808453500270844, 'train_batch_size': 64},
#    {'train_loss': 0.3184216320514679, 'train_batch_size': 64},
#    {'train_loss': 0.11621829867362976, 'train_batch_size': 64},
#    {'train_loss': 0.18193647265434265, 'train_batch_size': 64},
#    {'train_loss': 0.30527356266975403, 'train_batch_size': 64},
#    {'train_loss': 0.3700597286224365, 'train_batch_size': 64},
#    {'train_loss': 0.32697293162345886, 'train_batch_size': 64},
#    {'train_loss': 0.16219672560691833, 'train_batch_size': 64},
#    {'train_loss': 0.2982318103313446, 'train_batch_size': 64},
#    {'train_loss': 0.12164632230997086, 'train_batch_size': 64},
#    {'train_loss': 0.2929919362068176, 'train_batch_size': 64},
#    {'train_loss': 0.20586802065372467, 'train_batch_size': 64},
#    {'train_loss': 0.10600492358207703, 'train_batch_size': 64},
#    {'train_loss': 0.2027369737625122, 'train_batch_size': 64},
#    {'train_loss': 0.12555289268493652, 'train_batch_size': 64},
#    {'train_loss': 0.2517840266227722, 'train_batch_size': 64},
#    {'train_loss': 0.13718856871128082, 'train_batch_size': 64},
#    {'train_loss': 0.0871979296207428, 'train_batch_size': 64},
#    {'train_loss': 0.1638239473104477, 'train_batch_size': 64},
#    {'train_loss': 0.059474438428878784, 'train_batch_size': 64},
#    {'train_loss': 0.19809770584106445, 'train_batch_size': 64},
#    {'train_loss': 0.09074442833662033, 'train_batch_size': 64},
#    {'train_loss': 0.22670242190361023, 'train_batch_size': 64},
#    {'train_loss': 0.07663131505250931, 'train_batch_size': 64},
#    {'train_loss': 0.13952042162418365, 'train_batch_size': 64},
#    {'train_loss': 0.18659968674182892, 'train_batch_size': 64},
#    {'train_loss': 0.18346868455410004, 'train_batch_size': 64},
#    {'train_loss': 0.07059378176927567, 'train_batch_size': 64},
#    {'train_loss': 0.09010262787342072, 'train_batch_size': 64},
#    {'train_loss': 0.1394585818052292, 'train_batch_size': 64},
#    {'train_loss': 0.2850658595561981, 'train_batch_size': 64},
#    {'train_loss': 0.5051652789115906, 'train_batch_size': 64},
#    {'train_loss': 0.3803598880767822, 'train_batch_size': 64},
#    {'train_loss': 0.20789344608783722, 'train_batch_size': 64},
#    {'train_loss': 0.15216313302516937, 'train_batch_size': 64},
#    {'train_loss': 0.33064138889312744, 'train_batch_size': 64},
#    {'train_loss': 0.10182914137840271, 'train_batch_size': 64},
#    {'train_loss': 0.06541497260332108, 'train_batch_size': 64},
#    {'train_loss': 0.1510610282421112, 'train_batch_size': 64},
#    {'train_loss': 0.3306865096092224, 'train_batch_size': 64},
#    {'train_loss': 0.5049302577972412, 'train_batch_size': 64},
#    {'train_loss': 0.22557155787944794, 'train_batch_size': 64},
#    {'train_loss': 0.244431272149086, 'train_batch_size': 64},
#    {'train_loss': 0.1363155096769333, 'train_batch_size': 64},
#    {'train_loss': 0.08417507261037827, 'train_batch_size': 64},
#    {'train_loss': 0.11959464848041534, 'train_batch_size': 64},
#    {'train_loss': 0.35150444507598877, 'train_batch_size': 64},
#    {'train_loss': 0.21676349639892578, 'train_batch_size': 64},
#    {'train_loss': 0.07740768790245056, 'train_batch_size': 64},
#    {'train_loss': 0.1399393081665039, 'train_batch_size': 64},
#    {'train_loss': 0.10570456087589264, 'train_batch_size': 64},
#    {'train_loss': 0.3663717806339264, 'train_batch_size': 64},
#    {'train_loss': 0.07678698003292084, 'train_batch_size': 64},
#    {'train_loss': 0.29479721188545227, 'train_batch_size': 64},
#    {'train_loss': 0.28841549158096313, 'train_batch_size': 64},
#    {'train_loss': 0.21319252252578735, 'train_batch_size': 64},
#    {'train_loss': 0.14013752341270447, 'train_batch_size': 64},
#    {'train_loss': 0.17911125719547272, 'train_batch_size': 64},
#    {'train_loss': 0.15287402272224426, 'train_batch_size': 64},
#    {'train_loss': 0.13284340500831604, 'train_batch_size': 64},
#    {'train_loss': 0.24575328826904297, 'train_batch_size': 64},
#    {'train_loss': 0.13620348274707794, 'train_batch_size': 64},
#    {'train_loss': 0.0628325343132019, 'train_batch_size': 64},
#    {'train_loss': 0.041453391313552856, 'train_batch_size': 64},
#    {'train_loss': 0.1381600797176361, 'train_batch_size': 64},
#    {'train_loss': 0.2492942065000534, 'train_batch_size': 64},
#    {'train_loss': 0.24943166971206665, 'train_batch_size': 64},
#    {'train_loss': 0.19743303954601288, 'train_batch_size': 64},
#    {'train_loss': 0.1611141860485077, 'train_batch_size': 64},
#    {'train_loss': 0.058975495398044586, 'train_batch_size': 64},
#    {'train_loss': 0.1366667002439499, 'train_batch_size': 64},
#    {'train_loss': 0.12644310295581818, 'train_batch_size': 64},
#    {'train_loss': 0.06136865168809891, 'train_batch_size': 64},
#    {'train_loss': 0.09789637476205826, 'train_batch_size': 64},
#    {'train_loss': 0.13427814841270447, 'train_batch_size': 64},
#    {'train_loss': 0.18865251541137695, 'train_batch_size': 64},
#    {'train_loss': 0.09438885748386383, 'train_batch_size': 64},
#    {'train_loss': 0.06884866207838058, 'train_batch_size': 64},
#    {'train_loss': 0.3341684639453888, 'train_batch_size': 64},
#    {'train_loss': 0.12134218215942383, 'train_batch_size': 64},
#    {'train_loss': 0.28273898363113403, 'train_batch_size': 64},
#    {'train_loss': 0.4601730406284332, 'train_batch_size': 64},
#    {'train_loss': 0.20553620159626007, 'train_batch_size': 64},
#    {'train_loss': 0.07360201328992844, 'train_batch_size': 64},
#    {'train_loss': 0.0802546814084053, 'train_batch_size': 64},
#    {'train_loss': 0.08972257375717163, 'train_batch_size': 64},
#    {'train_loss': 0.0711188018321991, 'train_batch_size': 64},
#    {'train_loss': 0.044663213193416595, 'train_batch_size': 64},
#    {'train_loss': 0.09527437388896942, 'train_batch_size': 64},
#    {'train_loss': 0.1410997062921524, 'train_batch_size': 64},
#    {'train_loss': 0.29373958706855774, 'train_batch_size': 64},
#    {'train_loss': 0.18325947225093842, 'train_batch_size': 64},
#    {'train_loss': 0.21341553330421448, 'train_batch_size': 64},
#    {'train_loss': 0.4469383656978607, 'train_batch_size': 64},
#    {'train_loss': 0.25864216685295105, 'train_batch_size': 64},
#    {'train_loss': 0.18886303901672363, 'train_batch_size': 64},
#    {'train_loss': 0.11578407138586044, 'train_batch_size': 64},
#    {'train_loss': 0.21458901464939117, 'train_batch_size': 64},
#    {'train_loss': 0.17794504761695862, 'train_batch_size': 64},
#    {'train_loss': 0.06620509177446365, 'train_batch_size': 64},
#    {'train_loss': 0.07726078480482101, 'train_batch_size': 64},
#    {'train_loss': 0.07150684297084808, 'train_batch_size': 64},
#    {'train_loss': 0.09416861087083817, 'train_batch_size': 64},
#    {'train_loss': 0.2680490016937256, 'train_batch_size': 64},
#    {'train_loss': 0.17125307023525238, 'train_batch_size': 64},
#    {'train_loss': 0.1679881066083908, 'train_batch_size': 64},
#    {'train_loss': 0.1584453582763672, 'train_batch_size': 64},
#    {'train_loss': 0.17781223356723785, 'train_batch_size': 64},
#    {'train_loss': 0.19131697714328766, 'train_batch_size': 64},
#    {'train_loss': 0.1355520337820053, 'train_batch_size': 64},
#    {'train_loss': 0.22903001308441162, 'train_batch_size': 64},
#    {'train_loss': 0.21864910423755646, 'train_batch_size': 64},
#    {'train_loss': 0.05029980465769768, 'train_batch_size': 64},
#    {'train_loss': 0.12112552672624588, 'train_batch_size': 64},
#    {'train_loss': 0.11868207901716232, 'train_batch_size': 64},
#    {'train_loss': 0.08357720822095871, 'train_batch_size': 64},
#    {'train_loss': 0.1276226043701172, 'train_batch_size': 64},
#    {'train_loss': 0.07155515998601913, 'train_batch_size': 64},
#    {'train_loss': 0.19828246533870697, 'train_batch_size': 64},
#    {'train_loss': 0.06530732661485672, 'train_batch_size': 64},
#    {'train_loss': 0.1092563197016716, 'train_batch_size': 64},
#    {'train_loss': 0.07643120735883713, 'train_batch_size': 64},
#    {'train_loss': 0.09786778688430786, 'train_batch_size': 64},
#    {'train_loss': 0.27222245931625366, 'train_batch_size': 64},
#    {'train_loss': 0.20410217344760895, 'train_batch_size': 64},
#    {'train_loss': 0.15760263800621033, 'train_batch_size': 64},
#    {'train_loss': 0.10042180866003036, 'train_batch_size': 64},
#    {'train_loss': 0.07950874418020248, 'train_batch_size': 64},
#    {'train_loss': 0.0852593407034874, 'train_batch_size': 64},
#    {'train_loss': 0.09360682219266891, 'train_batch_size': 64},
#    {'train_loss': 0.20187298953533173, 'train_batch_size': 64},
#    {'train_loss': 0.29814186692237854, 'train_batch_size': 64},
#    {'train_loss': 0.212314635515213, 'train_batch_size': 64},
#    {'train_loss': 0.19057254493236542, 'train_batch_size': 64},
#    {'train_loss': 0.06785042583942413, 'train_batch_size': 64},
#    {'train_loss': 0.11505070328712463, 'train_batch_size': 64},
#    {'train_loss': 0.05542642995715141, 'train_batch_size': 64},
#    {'train_loss': 0.2530071437358856, 'train_batch_size': 64},
#    {'train_loss': 0.1647508442401886, 'train_batch_size': 64},
#    {'train_loss': 0.27430352568626404, 'train_batch_size': 64},
#    {'train_loss': 0.06765257567167282, 'train_batch_size': 64},
#    {'train_loss': 0.11291468888521194, 'train_batch_size': 64},
#    {'train_loss': 0.13888150453567505, 'train_batch_size': 64},
#    {'train_loss': 0.10141614079475403, 'train_batch_size': 64},
#    {'train_loss': 0.1336270272731781, 'train_batch_size': 64},
#    {'train_loss': 0.0981583446264267, 'train_batch_size': 64},
#    {'train_loss': 0.16755153238773346, 'train_batch_size': 64},
#    {'train_loss': 0.11088937520980835, 'train_batch_size': 64},
#    {'train_loss': 0.15815469622612, 'train_batch_size': 64},
#    {'train_loss': 0.08860158175230026, 'train_batch_size': 64},
#    {'train_loss': 0.17576394975185394, 'train_batch_size': 64},
#    {'train_loss': 0.11071726679801941, 'train_batch_size': 64},
#    {'train_loss': 0.15643078088760376, 'train_batch_size': 64},
#    {'train_loss': 0.0482211671769619, 'train_batch_size': 64},
#    {'train_loss': 0.1996913105249405, 'train_batch_size': 64},
#    {'train_loss': 0.12222471833229065, 'train_batch_size': 64},
#    {'train_loss': 0.06978686153888702, 'train_batch_size': 64},
#    {'train_loss': 0.2443733662366867, 'train_batch_size': 64},
#    {'train_loss': 0.12687119841575623, 'train_batch_size': 64},
#    {'train_loss': 0.038918256759643555, 'train_batch_size': 64},
#    {'train_loss': 0.05221062898635864, 'train_batch_size': 64},
#    {'train_loss': 0.15033473074436188, 'train_batch_size': 64},
#    {'train_loss': 0.07194972783327103, 'train_batch_size': 64},
#    {'train_loss': 0.10364203155040741, 'train_batch_size': 64},
#    {'train_loss': 0.1311817169189453, 'train_batch_size': 64},
#    {'train_loss': 0.18084195256233215, 'train_batch_size': 64},
#    {'train_loss': 0.18215881288051605, 'train_batch_size': 64},
#    {'train_loss': 0.18394514918327332, 'train_batch_size': 64},
#    {'train_loss': 0.22821055352687836, 'train_batch_size': 64},
#    {'train_loss': 0.07091255486011505, 'train_batch_size': 64},
#    {'train_loss': 0.0465560145676136, 'train_batch_size': 64},
#    {'train_loss': 0.03026324324309826, 'train_batch_size': 64},
#    {'train_loss': 0.15687669813632965, 'train_batch_size': 64},
#    {'train_loss': 0.19894738495349884, 'train_batch_size': 64},
#    {'train_loss': 0.09199239313602448, 'train_batch_size': 64},
#    {'train_loss': 0.054695285856723785, 'train_batch_size': 64},
#    {'train_loss': 0.054342616349458694, 'train_batch_size': 64},
#    {'train_loss': 0.017854636535048485, 'train_batch_size': 64},
#    {'train_loss': 0.09668292105197906, 'train_batch_size': 64},
#    {'train_loss': 0.09661758691072464, 'train_batch_size': 64},
#    {'train_loss': 0.0937034860253334, 'train_batch_size': 64},
#    {'train_loss': 0.01763004995882511, 'train_batch_size': 64},
#    {'train_loss': 0.07064409554004669, 'train_batch_size': 64},
#    {'train_loss': 0.01572643220424652, 'train_batch_size': 64},
#    {'train_loss': 0.018784433603286743, 'train_batch_size': 64},
#    {'train_loss': 0.0939774364233017, 'train_batch_size': 64},
#    {'train_loss': 0.13575264811515808, 'train_batch_size': 64},
#    {'train_loss': 0.022618502378463745, 'train_batch_size': 64},
#    {'train_loss': 0.012293551117181778, 'train_batch_size': 64},
#    {'train_loss': 0.05056017264723778, 'train_batch_size': 64},
#    {'train_loss': 0.02596197836101055, 'train_batch_size': 64},
#    {'train_loss': 0.034041013568639755, 'train_batch_size': 64},
#    {'train_loss': 0.1397133618593216, 'train_batch_size': 64},
#    {'train_loss': 0.18375179171562195, 'train_batch_size': 64},
#    {'train_loss': 0.159613698720932, 'train_batch_size': 64},
#    {'train_loss': 0.13265974819660187, 'train_batch_size': 64},
#    {'train_loss': 0.015639785677194595, 'train_batch_size': 64},
#    {'train_loss': 0.05481620505452156, 'train_batch_size': 64},
#    {'train_loss': 0.20651231706142426, 'train_batch_size': 64},
#    {'train_loss': 0.6129888892173767, 'train_batch_size': 64},
#    {'train_loss': 0.3103567957878113, 'train_batch_size': 64},
#    {'train_loss': 0.024805473163723946, 'train_batch_size': 64},
#    {'train_loss': 0.4217321574687958, 'train_batch_size': 64},
#    {'train_loss': 0.05761779099702835, 'train_batch_size': 64},
#    {'valid_loss': 0.057645853608846664, 'valid_batch_size': 64},
#    {'valid_loss': 0.12011327594518661, 'valid_batch_size': 64},
#    {'valid_loss': 0.3147709369659424, 'valid_batch_size': 64},
#    {'valid_loss': 0.07384590059518814, 'valid_batch_size': 64},
#    {'valid_loss': 0.07119007408618927, 'valid_batch_size': 64},
#    {'valid_loss': 0.028438406065106392, 'valid_batch_size': 64},
# ...
#    {'train_loss': 0.08286898583173752, 'train_batch_size': 64},
#    {'train_loss': 0.11462661623954773, 'train_batch_size': 64},
#    {'train_loss': 0.0029757849406450987, 'train_batch_size': 64},
#    {'train_loss': 0.0051864380948245525, 'train_batch_size': 64},
#    {'train_loss': 0.011415154673159122, 'train_batch_size': 64},
#    {'train_loss': 0.006920395419001579, 'train_batch_size': 64},
#    {'train_loss': 0.009801128879189491, 'train_batch_size': 64},
#    {'train_loss': 0.11343458294868469, 'train_batch_size': 64},
#    {'train_loss': 0.004208497237414122, 'train_batch_size': 64},
#    {'train_loss': 0.013154150918126106, 'train_batch_size': 64},
#    {'train_loss': 0.004211456514894962, 'train_batch_size': 64},
#    {'train_loss': 0.0880204439163208, 'train_batch_size': 64},
#    {'train_loss': 0.007738604675978422, 'train_batch_size': 64},
#    {'train_loss': 0.01833483576774597, 'train_batch_size': 64},
#    {'train_loss': 0.05277650058269501, 'train_batch_size': 64},
#    {'train_loss': 0.01677979901432991, 'train_batch_size': 64},
#    {'train_loss': 0.030656103044748306, 'train_batch_size': 64},
#    {'train_loss': 0.1651802957057953, 'train_batch_size': 64},
#    {'train_loss': 0.03279145434498787, 'train_batch_size': 64},
#    {'train_loss': 0.015327835455536842, 'train_batch_size': 64},
#    {'train_loss': 0.04424525797367096, 'train_batch_size': 64},
#    {'train_loss': 0.01909368671476841, 'train_batch_size': 64},
#    {'train_loss': 0.05868862569332123, 'train_batch_size': 64},
#    {'train_loss': 0.0340118482708931, 'train_batch_size': 64},
#    {'train_loss': 0.009367755614221096, 'train_batch_size': 64},
#    {'train_loss': 0.001296129310503602, 'train_batch_size': 64},
#    {'train_loss': 0.025131545960903168, 'train_batch_size': 64},
#    {'train_loss': 0.006067265290766954, 'train_batch_size': 64},
#    {'train_loss': 0.005877501331269741, 'train_batch_size': 64},
#    {'train_loss': 0.0030636589508503675, 'train_batch_size': 64},
#    {'train_loss': 0.000653986120596528, 'train_batch_size': 64},
#    {'train_loss': 0.029130658134818077, 'train_batch_size': 64},
#    {'train_loss': 0.02058461867272854, 'train_batch_size': 64},
#    {'train_loss': 0.0005167966592125595, 'train_batch_size': 64},
#    {'train_loss': 0.007358105853199959, 'train_batch_size': 64},
#    {'train_loss': 0.025388769805431366, 'train_batch_size': 64},
#    {'train_loss': 0.002315828111022711, 'train_batch_size': 64},
#    {'train_loss': 0.003152766264975071, 'train_batch_size': 64},
#    {'train_loss': 0.003705849638208747, 'train_batch_size': 64},
#    {'train_loss': 0.01583099737763405, 'train_batch_size': 64},
#    {'train_loss': 0.001205976470373571, 'train_batch_size': 64},
#    {'train_loss': 0.0007155514904297888, 'train_batch_size': 64},
#    {'train_loss': 0.025353506207466125, 'train_batch_size': 64},
#    {'train_loss': 0.009794263169169426, 'train_batch_size': 64},
#    {'train_loss': 0.09635928273200989, 'train_batch_size': 64},
#    {'train_loss': 0.050728898495435715, 'train_batch_size': 64},
#    {'train_loss': 0.0017949751345440745, 'train_batch_size': 64},
#    {'train_loss': 0.0009204858797602355, 'train_batch_size': 64},
#    {'train_loss': 0.03855181857943535, 'train_batch_size': 64},
#    {'train_loss': 0.2098015695810318, 'train_batch_size': 64},
#    {'train_loss': 0.06462477892637253, 'train_batch_size': 64},
#    {'train_loss': 0.044864434748888016, 'train_batch_size': 64},
#    {'train_loss': 0.4653940200805664, 'train_batch_size': 64},
#    {'train_loss': 0.003729461459442973, 'train_batch_size': 64},
#    {'valid_loss': 0.0020053761545568705, 'valid_batch_size': 64},
#    {'valid_loss': 0.016758320853114128, 'valid_batch_size': 64},
#    {'valid_loss': 0.15626399219036102, 'valid_batch_size': 64},
#    {'valid_loss': 0.04578355699777603, 'valid_batch_size': 64},
#    {'valid_loss': 0.004967580549418926, 'valid_batch_size': 64},
#    {'valid_loss': 0.001977217383682728, 'valid_batch_size': 64},
#    {'valid_loss': 0.04303736984729767, 'valid_batch_size': 64},
#    {'valid_loss': 0.15754784643650055, 'valid_batch_size': 64},
#    {'valid_loss': 0.00763984490185976, 'valid_batch_size': 64},
#    {'valid_loss': 0.09640023857355118, 'valid_batch_size': 64},
#    {'valid_loss': 0.0015651076100766659, 'valid_batch_size': 64},
#    {'valid_loss': 0.027977967634797096, 'valid_batch_size': 64},
#    {'valid_loss': 0.010539814829826355, 'valid_batch_size': 64},
#    {'valid_loss': 0.061735738068819046, 'valid_batch_size': 64},
#    {'valid_loss': 0.06871890276670456, 'valid_batch_size': 64},
#    {'valid_loss': 0.01783728040754795, 'valid_batch_size': 64},
#    {'valid_loss': 0.04651603847742081, 'valid_batch_size': 64},
#    {'valid_loss': 0.028116125613451004, 'valid_batch_size': 64},
#    {'valid_loss': 0.005218165460973978, 'valid_batch_size': 64},
#    {'valid_loss': 0.028658635914325714, 'valid_batch_size': 64},
#    {'valid_loss': 0.03678768500685692, 'valid_batch_size': 64},
#    {'valid_loss': 0.12584587931632996, 'valid_batch_size': 64},
#    {'valid_loss': 0.0016867319354787469, 'valid_batch_size': 64},
#    {'valid_loss': 0.022475244477391243, 'valid_batch_size': 64},
#    {'valid_loss': 0.001182858133688569, 'valid_batch_size': 64},
#    {'valid_loss': 0.12012987583875656, 'valid_batch_size': 64},
#    {'valid_loss': 0.025887301191687584, 'valid_batch_size': 64},
#    {'valid_loss': 0.06895380467176437, 'valid_batch_size': 64},
#    {'valid_loss': 0.0004112409078516066, 'valid_batch_size': 64},
#    {'valid_loss': 0.0015155788278207183, 'valid_batch_size': 64},
#    {'valid_loss': 0.03739754855632782, 'valid_batch_size': 64},
#    {'valid_loss': 0.04734134301543236, 'valid_batch_size': 64},
#    {'valid_loss': 0.0032985275611281395, 'valid_batch_size': 64},
#    {'valid_loss': 0.09770165383815765, 'valid_batch_size': 64},
#    {'valid_loss': 0.0014302594354376197, 'valid_batch_size': 64},
#    {'valid_loss': 0.000333580857841298, 'valid_batch_size': 64},
#    {'valid_loss': 0.006770581007003784, 'valid_batch_size': 64},
#    {'valid_loss': 0.10108374804258347, 'valid_batch_size': 64},
#    {'valid_loss': 0.008639403618872166, 'valid_batch_size': 64},
#    {'valid_loss': 0.03628603368997574, 'valid_batch_size': 64},
#    {'valid_loss': 0.035384371876716614, 'valid_batch_size': 64},
#    {'valid_loss': 0.07934582233428955, 'valid_batch_size': 64},
#    {'valid_loss': 0.10634933412075043, 'valid_batch_size': 64},
#    {'valid_loss': 0.008173935115337372, 'valid_batch_size': 64},
#    {'valid_loss': 0.01133925374597311, 'valid_batch_size': 64},
#    {'valid_loss': 0.059462253004312515, 'valid_batch_size': 64},
#    {'valid_loss': 0.0016462247585877776, 'valid_batch_size': 64},
#    {'valid_loss': 0.06816597282886505, 'valid_batch_size': 64},
#    {'valid_loss': 0.002209519501775503, 'valid_batch_size': 64},
#    {'valid_loss': 0.03504716232419014, 'valid_batch_size': 64},
#    {'valid_loss': 0.009434166364371777, 'valid_batch_size': 64},
#    {'valid_loss': 0.012255323119461536, 'valid_batch_size': 64},
#    {'valid_loss': 0.001790233887732029, 'valid_batch_size': 64},
#    {'valid_loss': 0.0019083649385720491, 'valid_batch_size': 64},
#    {'valid_loss': 0.043023526668548584, 'valid_batch_size': 64},
#    {'valid_loss': 0.06971874088048935, 'valid_batch_size': 64},
#    {'valid_loss': 0.00931063573807478, 'valid_batch_size': 64},
#    {'valid_loss': 0.08966372162103653, 'valid_batch_size': 64},
#    {'valid_loss': 0.03891211375594139, 'valid_batch_size': 64},
#    {'valid_loss': 0.0014927397714927793, 'valid_batch_size': 64},
#    {'valid_loss': 0.0002185582125093788, 'valid_batch_size': 64},
#    {'valid_loss': 0.0015990094980224967, 'valid_batch_size': 64},
#    {'valid_loss': 0.024011172354221344, 'valid_batch_size': 64},
#    {'valid_loss': 0.0013127147685736418, 'valid_batch_size': 64},
#    {'valid_loss': 0.09538362920284271, 'valid_batch_size': 64},
#    {'valid_loss': 0.006954983342438936, 'valid_batch_size': 64},
#    {'valid_loss': 0.023281432688236237, 'valid_batch_size': 64},
#    {'valid_loss': 0.04401194676756859, 'valid_batch_size': 64},
#    {'valid_loss': 0.008326764218509197, 'valid_batch_size': 64},
#    {'valid_loss': 0.15702390670776367, 'valid_batch_size': 64},
#    {'valid_loss': 0.009040361270308495, 'valid_batch_size': 64},
#    {'valid_loss': 0.005377332679927349, 'valid_batch_size': 64},
#    {'valid_loss': 0.015444149263203144, 'valid_batch_size': 64},
#    {'valid_loss': 0.0246808473020792, 'valid_batch_size': 64},
#    {'valid_loss': 0.0007698856061324477, 'valid_batch_size': 64},
#    {'valid_loss': 0.012697440572082996, 'valid_batch_size': 64},
#    {'valid_loss': 0.0030129114165902138, 'valid_batch_size': 64},
#    {'valid_loss': 0.16424380242824554, 'valid_batch_size': 64},
#    {'valid_loss': 0.05216602981090546, 'valid_batch_size': 64},
#    {'valid_loss': 0.10777732729911804, 'valid_batch_size': 64},
#    {'valid_loss': 0.05962362885475159, 'valid_batch_size': 64},
#    {'valid_loss': 0.09198147058486938, 'valid_batch_size': 64},
#    {'valid_loss': 0.09751469641923904, 'valid_batch_size': 64},
#    {'valid_loss': 0.041506510227918625, 'valid_batch_size': 64},
#    {'valid_loss': 0.058519840240478516, 'valid_batch_size': 64},
#    {'valid_loss': 0.003777081845328212, 'valid_batch_size': 64},
#    {'valid_loss': 0.1234545037150383, 'valid_batch_size': 64},
#    {'valid_loss': 0.002344155451282859, 'valid_batch_size': 64},
#    {'valid_loss': 0.013948983512818813, 'valid_batch_size': 64},
#    {'valid_loss': 0.02202753908932209, 'valid_batch_size': 64},
#    {'valid_loss': 0.05788333714008331, 'valid_batch_size': 64},
#    {'valid_loss': 0.006252456922084093, 'valid_batch_size': 64},
#    {'valid_loss': 0.07186282426118851, 'valid_batch_size': 64},
#    {'valid_loss': 0.0028407834470272064, 'valid_batch_size': 64},
#    {'valid_loss': 0.014326411299407482, 'valid_batch_size': 64},
#    {'valid_loss': 0.10264134407043457, 'valid_batch_size': 64},
#    {'valid_loss': 0.0016733093652874231, 'valid_batch_size': 64},
#    {'valid_loss': 0.10705190896987915, 'valid_batch_size': 64},
#    {'valid_loss': 0.03045082837343216, 'valid_batch_size': 64},
#    {'valid_loss': 0.08526953309774399, 'valid_batch_size': 64},
#    {'valid_loss': 0.023894093930721283, 'valid_batch_size': 64},
#    {'valid_loss': 0.008442134596407413, 'valid_batch_size': 64},
#    {'valid_loss': 0.003055902663618326, 'valid_batch_size': 64},
#    {'valid_loss': 0.0004454236477613449, 'valid_batch_size': 64},
#    {'valid_loss': 0.0581376850605011, 'valid_batch_size': 64},
#    {'valid_loss': 0.0017860553925856948, 'valid_batch_size': 64},
#    {'valid_loss': 0.023537956178188324, 'valid_batch_size': 64},
#    {'valid_loss': 0.06836089491844177, 'valid_batch_size': 64},
#    {'valid_loss': 0.0231741052120924, 'valid_batch_size': 64},
#    {'valid_loss': 0.0853571742773056, 'valid_batch_size': 64},
#    {'valid_loss': 0.11153556406497955, 'valid_batch_size': 64},
#    {'valid_loss': 0.0006461610901169479, 'valid_batch_size': 64},
#    {'valid_loss': 0.019198089838027954, 'valid_batch_size': 64},
#    {'valid_loss': 0.09761006385087967, 'valid_batch_size': 64},
#    {'valid_loss': 0.03638177365064621, 'valid_batch_size': 64},
#    {'valid_loss': 0.000954455288592726, 'valid_batch_size': 64},
#    {'valid_loss': 0.01590169221162796, 'valid_batch_size': 64},
#    {'valid_loss': 0.08060889691114426, 'valid_batch_size': 64},
#    {'valid_loss': 0.026889197528362274, 'valid_batch_size': 64},
#    {'valid_loss': 0.0020278599113225937, 'valid_batch_size': 64},
#    {'valid_loss': 0.008223013021051884, 'valid_batch_size': 64},
#    {'valid_loss': 0.04894217476248741, 'valid_batch_size': 64},
#    {'valid_loss': 0.026607966050505638, 'valid_batch_size': 64},
#    {'valid_loss': 0.010195550508797169, 'valid_batch_size': 64},
#    {'valid_loss': 0.0038859043270349503, 'valid_batch_size': 64},
#    {'valid_loss': 0.020518943667411804, 'valid_batch_size': 64},
#    {'valid_loss': 0.006883883848786354, 'valid_batch_size': 64},
#    {'valid_loss': 0.004544238094240427, 'valid_batch_size': 64},
#    {'valid_loss': 0.17671678960323334, 'valid_batch_size': 64},
#    {'valid_loss': 0.0043051112443208694, 'valid_batch_size': 64},
#    {'valid_loss': 0.0033192525152117014, 'valid_batch_size': 64},
#    {'valid_loss': 0.011485619470477104, 'valid_batch_size': 64},
#    {'valid_loss': 0.0763934776186943, 'valid_batch_size': 64},
#    {'valid_loss': 0.0003977753804065287, 'valid_batch_size': 64},
#    {'valid_loss': 0.0026314547285437584, 'valid_batch_size': 64},
#    {'valid_loss': 0.08461417257785797, 'valid_batch_size': 64},
#    {'valid_loss': 0.22850194573402405, 'valid_batch_size': 64},
#    {'valid_loss': 0.05122276768088341, 'valid_batch_size': 64},
#    {'valid_loss': 0.03402888402342796, 'valid_batch_size': 64},
#    {'valid_loss': 0.10364891588687897, 'valid_batch_size': 64},
#    {'valid_loss': 0.010619020089507103, 'valid_batch_size': 64},
#    {'valid_loss': 0.0056735859252512455, 'valid_batch_size': 64},
#    {'valid_loss': 0.010856542736291885, 'valid_batch_size': 64},
#    {'valid_loss': 0.00201437808573246, 'valid_batch_size': 64},
#    {'valid_loss': 0.06512647867202759, 'valid_batch_size': 64},
#    {'valid_loss': 0.0008266069926321507, 'valid_batch_size': 64},
#    {'valid_loss': 0.008660204708576202, 'valid_batch_size': 64},
#    {'valid_loss': 0.15902157127857208, 'valid_batch_size': 64},
#    {'valid_loss': 0.04877294972538948, 'valid_batch_size': 64},
#    {'valid_loss': 0.02345368079841137, 'valid_batch_size': 64},
#    {'valid_loss': 0.11504074186086655, 'valid_batch_size': 64},
#    {'valid_loss': 0.11996106803417206, 'valid_batch_size': 64},
#    {'valid_loss': 0.004464398138225079, 'valid_batch_size': 64},
#    {'valid_loss': 0.00157737301196903, 'valid_batch_size': 64},
#    {'valid_loss': 0.00019024600624106824, 'valid_batch_size': 64},
#    {'valid_loss': 0.026388108730316162, 'valid_batch_size': 64},
#    {'valid_loss': 0.0016857052687555552, 'valid_batch_size': 64},
#    {'valid_loss': 0.1740175485610962, 'valid_batch_size': 64},
#    {'valid_loss': 0.001549312612041831, 'valid_batch_size': 64},
#    {'valid_loss': 0.033847637474536896, 'valid_batch_size': 64},
#    {'valid_loss': 0.1482856571674347, 'valid_batch_size': 64},
#    {'valid_loss': 0.0214700810611248, 'valid_batch_size': 64},
#    {'valid_loss': 0.0032770130783319473, 'valid_batch_size': 64},
#    {'valid_loss': 0.0006997169111855328, 'valid_batch_size': 64},
#    {'valid_loss': 0.0015538560692220926, 'valid_batch_size': 64},
#    {'valid_loss': 0.0008003948023542762, 'valid_batch_size': 64},
#    {'valid_loss': 0.0003504707710817456, 'valid_batch_size': 64},
#    {'valid_loss': 0.0012115614954382181, 'valid_batch_size': 64},
#    {'valid_loss': 0.051427554339170456, 'valid_batch_size': 64},
#    {'valid_loss': 0.00012859932030551136, 'valid_batch_size': 64},
#    {'valid_loss': 0.0007447579992003739, 'valid_batch_size': 64},
#    {'valid_loss': 0.16894705593585968, 'valid_batch_size': 64},
#    {'valid_loss': 0.010987122543156147, 'valid_batch_size': 64},
#    {'valid_loss': 0.007180734071880579, 'valid_batch_size': 64},
#    {'valid_loss': 0.00016373427934013307, 'valid_batch_size': 64},
#    {'valid_loss': 0.08176330476999283, 'valid_batch_size': 64},
#    {'valid_loss': 0.008789959363639355, 'valid_batch_size': 64},
#    {'valid_loss': 0.007703087758272886, 'valid_batch_size': 64},
#    {'valid_loss': 0.005877896677702665, 'valid_batch_size': 64},
#    {'valid_loss': 0.000973023590631783, 'valid_batch_size': 64},
#    {'valid_loss': 0.006364688277244568, 'valid_batch_size': 64},
#    {'valid_loss': 0.015925826504826546, 'valid_batch_size': 64},
#    {'valid_loss': 0.019528768956661224, 'valid_batch_size': 64},
#    {'valid_loss': 0.0293162539601326, 'valid_batch_size': 64},
#    {'valid_loss': 0.08681468665599823, 'valid_batch_size': 64},
#    {'valid_loss': 0.12748758494853973, 'valid_batch_size': 64},
#    {'valid_loss': 0.015634117648005486, 'valid_batch_size': 64},
#    {'valid_loss': 0.007621403783559799, 'valid_batch_size': 32}],
#   'epoch': 10,
#   'train_batch_count': 750,
#   'valid_batch_count': 188,
#   'dur': 25.10363507270813,
#   'train_loss': 0.04408983891294338,
#   'train_loss_best': True,
#   'valid_loss': 0.038652379518840464,
#   'valid_loss_best': True,
#   'valid_acc': 0.9896666666666667,
#   'valid_acc_best': True}]

# %%
val_acc=[]
val_loss=[]
train_loss=[]
for i in range(10):
    val_acc.append(net.history[i]['valid_acc'])
    val_loss.append(net.history[i]['valid_loss'])
    train_loss.append(net.history[i]['train_loss'])
        
#print('avg val accuracy: {:.4f}'.format(val_acc/10))

# %%
plt.figure(figsize=(10,8))
plt.semilogy(train_loss, label='Train loss')
plt.semilogy(val_loss, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %%
from skorch import scoring

# %%
scoring.loss_scoring(net,train_dataset, y=y_train)
# Out:
# 0.018448845373111544

# %% [markdown]
# ## Prediction

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
y_pred = net.predict(test_dataset)
y_test = test_dataset.targets.numpy()

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9909

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 976,    0,    0,    0,    0,    0,    2,    1,    1,    0],
#        [   0, 1134,    0,    0,    0,    0,    0,    1,    0,    0],
#        [   2,    3, 1022,    1,    0,    0,    0,    3,    1,    0],
#        [   0,    0,    3, 1004,    0,    2,    0,    1,    0,    0],
#        [   0,    0,    0,    0,  975,    0,    0,    0,    1,    6],
#        [   1,    0,    0,    5,    0,  884,    1,    0,    0,    1],
#        [   5,    3,    0,    0,    2,    6,  940,    0,    2,    0],
#        [   0,    2,    5,    1,    0,    0,    0, 1017,    1,    2],
#        [   1,    0,    2,    1,    1,    2,    0,    0,  963,    4],
#        [   0,    2,    0,    2,    5,    3,    0,    3,    0,  994]])

# %%
plot_confusion_matrix(net,test_dataset, y_test.reshape(-1, 1))
plt.show()

# %% [markdown]
# ## K cross validation

# %%
from skorch.helper import SliceDataset

train_sliceable = SliceDataset(train_dataset)

# %%
torch.manual_seed(0)

net = NeuralNetClassifier(
    ConvNet,
    lr=1e-3,
    batch_size=64,
    optimizer=optim.Adam,
    max_epochs=10,
    criterion=nn.CrossEntropyLoss,
    iterator_train__num_workers=4,
    #iterator_train__shuffle=True,
    iterator_valid__num_workers=4,
    #iterator_valid__shuffle=True,
    device=DEVICE
)

# %%
scores = cross_val_score(net, train_sliceable,y_train, cv = 5, scoring = "accuracy")
# Out:
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.4717       0.9621        0.1191  18.9545
#       2        0.1441       0.9785        0.0767  20.0966
#       3        0.1078       0.9835        0.0556  19.6963
#       4        0.0929       0.9851        0.0519  19.4412
#       5        0.0777       0.9866        0.0440  20.1908
#       6        0.0680       0.9871        0.0437  19.5459
#       7        0.0634       0.9885        0.0401  19.6422
#       8        0.0586       0.9906        0.0333  20.1109
#       9        0.0529       0.9902        0.0357  19.9390
#      10        0.0475       0.9907        0.0333  19.7012
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.4641       0.9592        0.1408  20.4813
#       2        0.1559       0.9748        0.0894  19.7612
#       3        0.1163       0.9761        0.0818  19.7267
#       4        0.1013       0.9801        0.0640  20.3954
#       5        0.0883       0.9818        0.0610  20.2873
#       6        0.0757       0.9832        0.0571  19.9567
#       7        0.0706       0.9852        0.0536  20.0706
#       8        0.0636       0.9852        0.0500  20.0793
#       9        0.0581       0.9857        0.0525  19.2443
#      10        0.0537       0.9856        0.0519  20.5147
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.4472       0.9671        0.1156  19.6166
#       2        0.1532       0.9746        0.0858  19.3274
#       3        0.1166       0.9747        0.0838  20.2655
#       4        0.1003       0.9798        0.0666  19.5840
#       5        0.0848       0.9822        0.0628  19.2138
#       6        0.0727       0.9843        0.0567  20.4352
#       7        0.0647       0.9842        0.0537  19.4995
#       8        0.0603       0.9860        0.0488  19.5976
#       9        0.0582       0.9854        0.0546  20.2713
#      10        0.0544       0.9856        0.0506  19.4909
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.4359       0.9620        0.1305  19.5493
#       2        0.1389       0.9756        0.0854  20.0245
#       3        0.1014       0.9802        0.0687  19.7236
#       4        0.0849       0.9839        0.0607  19.4827
#       5        0.0735       0.9848        0.0575  20.0105
#       6        0.0631       0.9855        0.0516  19.5734
#       7        0.0563       0.9859        0.0510  19.0531
#       8        0.0541       0.9868        0.0472  20.2258
#       9        0.0483       0.9876        0.0424  19.6872
#      10        0.0431       0.9880        0.0433  19.2556
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.4237       0.9677        0.1121  21.1641
#       2        0.1370       0.9770        0.0784  20.4057
#       3        0.1052       0.9807        0.0662  19.3733
#       4        0.0877       0.9824        0.0571  20.4185
#       5        0.0761       0.9841        0.0530  19.5306
#       6        0.0667       0.9858        0.0497  19.8058
#       7        0.0620       0.9858        0.0496  20.4080
#       8        0.0532       0.9851        0.0512  19.5058
#       9        0.0541       0.9865        0.0500  19.5477
#      10        0.0491       0.9871        0.0488  20.5203

# %%
print('validation accuracy for each fold: {}'.format(scores))
print('avg validation accuracy: {:.3f}'.format(scores.mean()))
# Out:
# validation accuracy for each fold: [0.98791667 0.98933333 0.98491667 0.98683333 0.98775   ]
# avg validation accuracy: 0.987
